# %%
import sys
sys.path.append("/home/hugo/projetos-doutorado/mimo_emb_fts/src/embfts")
import pandas as pd
import matplotlib.pyplot as plt
from models.NonStationaryFtsPca import NonStationaryFtsPca
from pyFTS.benchmarks import Measures
from pyFTS.models.nonstationary import nsfts
import math
import datetime
import statistics
import numpy as np
from pyFTS.common import Util
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from util.DataSetUtil import DataSetUtil
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %% [markdown]
# ### Dataset Energy Appliance Kaggle

# %%
df = pd.read_csv('/home/hugo/projetos-doutorado/Appliance-Energy-Prediction/data/HomeC.csv', sep=',')
data = df.drop(labels=['time','House overall [kW]','cloudCover','summary','icon'], axis=1)
data.dropna(inplace=True)
y_appliance = data['use [kW]'].values
# data = df.loc[:,'lights':'Tdewpoint']
# Out:
# /home/hugo/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#data

# %% [markdown]
# ### Model: NonStationaryFtsPca - PCA-NSFTS

# %%
fts_pca = NonStationaryFtsPca(num_components_pca = 1,
                          fts_model = nsfts.NonStationaryFTS,
                          order_fts_model = 1,
                          npart = 5,
                          gamma = 0.5,
                          memory_window_error = 3)

# %% [markdown]
# ### Sliding Window PyFTS: PCA-NSFTS

# %%
result = {
     "window": [],
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}
steps_ahead = 1
tam = len(data)
n_windows = 30
windows_length = math.floor(tam / n_windows)
for ct, ttrain, ttest in Util.sliding_window(data, windows_length, 0.75, inc=1):
    if len(ttest) > 0:
        
        print('-' * 20)
        print(f'training window {(ct)}')
        #ttrain = ttrain.loc[:,'lights':'Tdewpoint']
        model_train, pca_train = fts_pca.run_train_pca_non_stationary(ttrain)
        #adfuller_test(pca_train)
        y_test_appliance = ttest['use [kW]'].values
        forecast, data_test = fts_pca.run_test_target(y_test_appliance,steps_ahead)
        
        
        #print("[{0: %H:%M:%S}]".format(datetime.datetime.now()) + f" getting statistics")
        rmse = Measures.rmse(y_test_appliance,forecast)
        mape = Measures.mape(y_test_appliance,forecast)
        smape = Measures.smape(y_test_appliance,forecast)
        mae = mean_absolute_error(y_test_appliance, forecast)
        r2 = r2_score(y_test_appliance, forecast)
        
        result["rmse"].append(rmse)
        result["mape"].append(mape)
        result["smape"].append(smape)
        result["mae"].append(mae)
        result["r2"].append(r2)
        result["window"].append(ct)
        
        
measures = pd.DataFrame(result)
# Out:
# --------------------
# training window 0
# --------------------
# training window 16797
# --------------------
# training window 33594
# --------------------
# training window 50391
# --------------------
# training window 67188
# --------------------
# training window 83985
# --------------------
# training window 100782
# --------------------
# training window 117579
# --------------------
# training window 134376
# --------------------
# training window 151173
# --------------------
# training window 167970
# --------------------
# training window 184767
# --------------------
# training window 201564
# --------------------
# training window 218361
# --------------------
# training window 235158
# --------------------
# training window 251955
# --------------------
# training window 268752
# --------------------
# training window 285549
# --------------------
# training window 302346
# --------------------
# training window 319143
# --------------------
# training window 335940
# ...

# %% [markdown]
# #### Sliding Windows Statistics:

# %%
print("Sliding Windows Statistics (test): ")
measures
# Out:
# Sliding Windows Statistics (test):
#     window      rmse        mape      smape       mae        r2
# 0        0  0.517597   33.324118  20.164242  0.392347  0.452542
# 1    16797  0.363448  207.612534  14.093780  0.262187  0.689522
# 2    33594  0.331227   42.399943  25.868985  0.269028  0.472208
# 3    50391  0.579492   35.752124  22.007234  0.476739  0.364685
# 4    67188  0.264816   79.145399  13.398442  0.176482  0.809422
# 5    83985  0.275295  268.910260  26.530720  0.252205  0.497466
# 6   100782  0.444609   56.546107  32.317318  0.367113  0.461812
# 7   117579  0.448787   44.152109  28.647327  0.310124  0.245643
# 8   134376  0.281553  369.423864  24.187619  0.242730  0.742757
# 9   151173  0.496200   83.383748  17.796878  0.246363  0.497763
# 10  167970  0.519610   77.548860  52.257545  0.439550  0.176858
# 11  184767  0.264695   38.446339  18.876065  0.191210  0.671470
# 12  201564  0.302994  121.063988  52.567017  0.222029  0.301203
# ...

# %% [markdown]
# #### Mean Statistics PCA-NSFTS:

# %%
final_result = {
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}

final_result["rmse"].append(statistics.mean(measures['rmse']))
final_result["mape"].append(statistics.mean(measures['mape']))
final_result["smape"].append(statistics.mean(measures['smape']))
final_result["mae"].append(statistics.mean(measures['mae']))
final_result["r2"].append(statistics.mean(measures['r2']))
        
final_measures_pca = pd.DataFrame(final_result)

print("Mean Statistics PCA-NSFTS (test): ")
final_measures_pca
# Out:
# Mean Statistics PCA-NSFTS (test):
#        rmse        mape      smape       mae        r2
# 0  0.486995  107.966575  30.609074  0.347046  0.517467

# %% [markdown]
# ### Sliding Window PyFTS: KPCA-NSFTS

# %%
result = {
     "window": [],
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}

tam = len(data)
n_windows = 30
windows_length = math.floor(tam / n_windows)
for ct, ttrain, ttest in Util.sliding_window(data, windows_length, 0.75, inc=1):
    if len(ttest) > 0:
        
        print('-' * 20)
        print(f'training window {(ct)}')
        #ttrain = ttrain.loc[:,'lights':'Tdewpoint']
        model_train, pca_train = fts_pca.run_train_kernel_pca_non_stationary(ttrain)
        y_test_appliance = ttest['use [kW]'].values
        forecast, data_test = fts_pca.run_test_target(y_test_appliance,steps_ahead)
        
        #print("[{0: %H:%M:%S}]".format(datetime.datetime.now()) + f" getting statistics")
        rmse = Measures.rmse(y_test_appliance,forecast)
        mape = Measures.mape(y_test_appliance,forecast)
        smape = Measures.smape(y_test_appliance,forecast)
        mae = mean_absolute_error(y_test_appliance, forecast)
        r2 = r2_score(y_test_appliance, forecast)
        
        result["rmse"].append(rmse)
        result["mape"].append(mape)
        result["smape"].append(smape)
        result["mae"].append(mae)
        result["r2"].append(r2)
        result["window"].append(ct)
        
measures = pd.DataFrame(result)
# Out:
# --------------------
# training window 0
# --------------------
# training window 16797
# --------------------
# training window 33594
# --------------------
# training window 50391
# --------------------
# training window 67188
# --------------------
# training window 83985
# --------------------
# training window 100782
# --------------------
# training window 117579
# --------------------
# training window 134376
# --------------------
# training window 151173
# --------------------
# training window 167970
# --------------------
# training window 184767
# --------------------
# training window 201564
# --------------------
# training window 218361
# --------------------
# training window 235158
# --------------------
# training window 251955
# --------------------
# training window 268752
# --------------------
# training window 285549
# --------------------
# training window 302346
# --------------------
# training window 319143
# --------------------
# training window 335940
# ...

# %% [markdown]
# #### Sliding Windows Statistics:

# %%
#print("Sliding Windows Statistics: ")
measures
# Out:
#     window      rmse        mape      smape       mae        r2
# 0        0  0.252897   27.592632  17.236455  0.220085  0.869307
# 1    16797  0.260500   67.940877  19.019069  0.228274  0.840500
# 2    33594  0.255287   43.297967  26.108983  0.230244  0.686478
# 3    50391  0.249459   23.988625  14.270202  0.216173  0.882268
# 4    67188  0.210554   42.619897  19.167789  0.183864  0.879520
# 5    83985  0.231559   53.220864  29.407629  0.206354  0.644456
# 6   100782  0.190427   34.780579  15.722171  0.160893  0.901274
# 7   117579  0.293929   43.635236  28.144935  0.255599  0.676422
# 8   134376  0.248442   99.566996  28.398918  0.214838  0.799703
# 9   151173  0.215432   47.166202  19.329031  0.171767  0.905329
# 10  167970  0.262953   40.545122  25.775642  0.226265  0.789197
# 11  184767  0.227025   57.251322  28.854945  0.197142  0.758326
# 12  201564  0.323354   95.106106  35.632204  0.192352  0.204132
# 13  218361  0.189377  301.981668  31.614699  0.171692  0.652539
# ...

# %% [markdown]
# #### Mean Statistics KPCA-NSFTS:

# %%
final_result = {
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}

final_result["rmse"].append(statistics.mean(measures['rmse']))
final_result["mape"].append(statistics.mean(measures['mape']))
final_result["smape"].append(statistics.mean(measures['smape']))
final_result["mae"].append(statistics.mean(measures['mae']))
final_result["r2"].append(statistics.mean(measures['r2']))
        
final_measures_kpca = pd.DataFrame(final_result)

print("Mean Statistics KPCA-NSFTS: ")
final_measures_kpca
# Out:
# Mean Statistics KPCA-NSFTS:
#        rmse       mape      smape       mae        r2
# 0  0.289634  63.960282  24.906167  0.223834  0.778568

# %% [markdown]
# ### Persistence method - Naive forecasting

# %%
y_appliance
# Out:
# array([0.93283333, 0.93433333, 0.93181667, ..., 1.9782    , 1.99095   ,
#               nan])

# %%
# Create a lag feature
var = pd.DataFrame(y_appliance)
dataframe = pd.concat([var.shift(1), var], axis=1)
dataframe.columns = ['t', 't+1']

# %%
# Create a baseline model (Naive model)
def model_persistence(x):
  return x

def test_persistence(test_X):
    predictions = list()
    for x in test_X:
        yhat = model_persistence(x)
        predictions.append(yhat)
    return predictions

# %% [markdown]
# ### Sliding Window PyFTS:Persistence

# %%
result = {
     "window": [],
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}

tam = len(data)
n_windows = 30
windows_length = math.floor(tam / n_windows)
for ct, ttrain, ttest in Util.sliding_window(dataframe[1:tam], windows_length, 0.75, inc=1):
    if len(ttest) > 0:
        
        print('-' * 20)
        print(f'training window {(ct)}')
        
        train_X, train_y = ttrain.iloc[:,0], ttrain.iloc[:,1]
        test_X, test_y = ttest.iloc[:,0], ttest.iloc[:,1]
        
        forecast = test_persistence(test_X)
        
        #print("[{0: %H:%M:%S}]".format(datetime.datetime.now()) + f" getting statistics")
        rmse = Measures.rmse(test_y,forecast)
        mape = Measures.mape(test_y,forecast)
        smape = Measures.smape(test_y,forecast)
        mae = mean_absolute_error(test_y, forecast)
        r2 = r2_score(test_y, forecast)
        
        result["rmse"].append(rmse)
        result["mape"].append(mape)
        result["smape"].append(smape)
        result["mae"].append(mae)
        result["r2"].append(r2)
        result["window"].append(ct)
        
measures = pd.DataFrame(result)
# Out:
# --------------------
# training window 0
# --------------------
# training window 16797
# --------------------
# training window 33594
# --------------------
# training window 50391
# --------------------
# training window 67188
# --------------------
# training window 83985
# --------------------
# training window 100782
# --------------------
# training window 117579
# --------------------
# training window 134376
# --------------------
# training window 151173
# --------------------
# training window 167970
# --------------------
# training window 184767
# --------------------
# training window 201564
# --------------------
# training window 218361
# --------------------
# training window 235158
# --------------------
# training window 251955
# --------------------
# training window 268752
# --------------------
# training window 285549
# --------------------
# training window 302346
# --------------------
# training window 319143
# --------------------
# training window 335940
# ...

# %% [markdown]
# #### Slidding window Persistence:

# %%
measures
# Out:
#     window      rmse        mape      smape       mae        r2
# 0        0  0.252897   27.592632  17.236455  0.220085  0.869307
# 1    16797  0.260500   67.940877  19.019069  0.228274  0.840500
# 2    33594  0.255287   43.297967  26.108983  0.230244  0.686478
# 3    50391  0.249459   23.988625  14.270202  0.216173  0.882268
# 4    67188  0.210554   42.619897  19.167789  0.183864  0.879520
# 5    83985  0.231559   53.220864  29.407629  0.206354  0.644456
# 6   100782  0.190427   34.780579  15.722171  0.160893  0.901274
# 7   117579  0.293929   43.635236  28.144935  0.255599  0.676422
# 8   134376  0.248442   99.566996  28.398918  0.214838  0.799703
# 9   151173  0.215432   47.166202  19.329031  0.171767  0.905329
# 10  167970  0.262953   40.545122  25.775642  0.226265  0.789197
# 11  184767  0.227025   57.251322  28.854945  0.197142  0.758326
# 12  201564  0.323354   95.106106  35.632204  0.192352  0.204132
# 13  218361  0.189377  301.981668  31.614699  0.171692  0.652539
# ...

# %% [markdown]
# #### Mean Statistics Persistence:

# %%
final_result = {
     "rmse": [],
     "mape": [],
     "smape": [],
     "mae": [],
     "r2": []
}

final_result["rmse"].append(statistics.mean(measures['rmse']))
final_result["mape"].append(statistics.mean(measures['mape']))
final_result["smape"].append(statistics.mean(measures['smape']))
final_result["mae"].append(statistics.mean(measures['mae']))
final_result["r2"].append(statistics.mean(measures['r2']))
        
final_measures_persistence = pd.DataFrame(final_result)

print("Mean Statistics Persistence: ")
final_measures_persistence
# Out:
# Mean Statistics Persistence:
#        rmse       mape      smape       mae        r2
# 0  0.289634  63.960282  24.906167  0.223834  0.778568

# %% [markdown]
# ### Skill Score

# %% [markdown]
# #### PCA-NSFTS

# %%
#1 - (forcasted metric / reference metric)
dif = final_measures_pca['rmse'] / final_measures_persistence['rmse']
ss = 1 - dif
print(ss)
# Out:
# 0    0.816293
# Name: rmse, dtype: float64

# %%
#GBM
dif = final_measures_pca['rmse'] / 66.21
ss = 1 - dif
print(ss)
# Out:
# 0    0.820346
# Name: rmse, dtype: float64

# %%
#MLP
dif = final_measures_pca['rmse'] / 59.84 #66.29
ss = 1 - dif
print(ss)
# Out:
# 0    0.801221
# Name: rmse, dtype: float64

# %%
#LSTM
dif = final_measures_pca['rmse'] / 21.39
ss = 1 - dif
print(ss)
# Out:
# 0    0.443903
# Name: rmse, dtype: float64

# %% [markdown]
# #### KPCA-NSFTS

# %%
dif = final_measures_kpca['rmse'] / final_measures_persistence['rmse']
ss = 1 - dif
print(ss)
# Out:
# 0    0.821834
# Name: rmse, dtype: float64

# %%
#GBM
dif = final_measures_kpca['rmse'] / 66.21
ss = 1 - dif
print(ss)
# Out:
# 0    0.825765
# Name: rmse, dtype: float64

# %%
#MLP
dif = final_measures_kpca['rmse'] / 59.84 #66.29
ss = 1 - dif
print(ss)
# Out:
# 0    0.807217
# Name: rmse, dtype: float64

# %%
#LSTM
dif = final_measures_kpca['rmse'] / 21.39
ss = 1 - dif
print(ss)
# Out:
# 0    0.460677
# Name: rmse, dtype: float64

# %%
model_train, pca_train = fts_pca.run_train_pca_non_stationary(data)
soda_file_name = '/home/hugo/projetos-doutorado/imp_doutorado/src/evolving_soda/temp/pca_soda.csv'
df_soda = pd.DataFrame(pca_train)
df_soda.to_csv(soda_file_name, index=False);

# %%
print(model_train)
# Out:
# Non Stationary FTS:
# A1 -> A0,A1,A2,A3
# A2 -> A0,A1,A2,A3,A4
# A0 -> A0,A1,A2
# A3 -> A1,A2,A3,A4
# A4 -> A2,A3,A4

# %%
# Grafico de comparação Original x Previsto para cada janela
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15, 3])
ax.plot(pca_train, label='Embedding')
#ax.plot(forecast, label='Forecast')
handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles, labels, loc=2, bbox_to_anchor=(1, 1))
plt.show()

# %%
model_train, pca_train = fts_pca.run_train_pca_non_stationary(data)
adfuller_test(pca_train)
# Out:
#     Augmented Dickey-Fuller Test on ""
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.6804
#  No. Lags Chosen       = 45
#  Critical value 1%     = -3.431
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0044. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
kpss_test(pca_train)
# Out:
# KPSS Test on ""
#     -----------------------------------------------
# KPSS Statistic: 28.78644922421138
# p-value: 0.01
# num lags: 45
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Result: The series is not stationary
# /home/hugo/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:2041: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# /home/hugo/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:2072: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
# ...

# %% [markdown]
# ## Forecast Horizon

# %%
train = sample_first_prows(data,0.75)
test = data.iloc[max(train.index):]
y_test = data.iloc[max(train.index):]['Appliances'].values

# %%
fts_pca = NonStationaryFtsPca(num_components_pca = 1,
                          fts_model = nsfts.NonStationaryFTS,
                          order_fts_model = 1,
                          npart = 5,
                          gamma = 0.5,
                          memory_window_error = 3)

# %%
model_train, pca_train = fts_pca.run_train_pca_non_stationary(train)

# %%
steps_ahead = 1
y_test_appliance = test['Appliances'].values
forecast, data_test = fts_pca.run_test_target(y_test_appliance,steps_ahead)

# %%
rmse = Measures.rmse(y_test_appliance[0:steps_ahead],forecast)
mape = Measures.mape(y_test_appliance[0:steps_ahead],forecast)
smape = Measures.smape(y_test_appliance[0:steps_ahead],forecast)

# %%
rmse
# Out:
# 206.15308978302872

# %%
forecast
# Out:
# [279.7960788345456,
#  278.9734382944247,
#  319.10060246490366,
#  361.3096631897995,
#  211.81377217806806,
#  105.48600815582228,
#  102.92414387414448,
#  90.85999148396378,
#  88.93403757757008,
#  100.11194013751795,
#  98.9027161698464,
#  99.3044328184941,
#  129.1396466429583,
#  259.15911594386364,
#  110.86754495205182,
#  110.60327925394806,
#  48.38958967858446,
#  109.98844003102532,
#  108.93834474585556,
#  108.99516103519879,
#  109.5115652435217,
#  109.52111931889365,
#  81.31257261788274,
#  90.46703397885682,
#  79.34041690447737,
#  79.62272973099417,
#  69.41166920776789,
#  79.47767431882146,
#  80.2476063059054,
#  69.4540813552782,
#  60.26529259021945,
#  60.27077294651372,
#  59.25291458995173,
#  79.19626459279507,
#  80.991423455827,
#  80.96902389241532,
#  68.827533809127,
#  79.06928462041924,
#  80.37104487385302,
#  189.41208113018445,
#  588.255016248817,
#  479.4388100885691,
#  200.36850927543617,
#  120.83640729718724,
#  154.94238685055115,
# ...
