# %% [markdown]
# ## Design of Experiments
#
# This research adopted the Sliding Window Cross Validation approach for evaluating the performance of a set of forecasting methods $\mathcal{M}$ over a set of datasets $\mathcal{D}$.
#
# Each dataset $\mathcal{d}_j \in \mathcal{D}$ was splited in $k = 31$ overlapped data windows with $W = 2000$ samples, each one of them shifted by $I = 200$ instances from left to the right.
#
# For each data window $\mathcal{d}_{w,j} \in \mathcal{d}_j$, where $w=1\ldots k$ and $j=1\ldots |\mathcal{D}|$, a forecasting model $\mathcal{m}_{i}^{\mathcal{d}_{w,j}}$ is trained and tested, for each forecasting method $\mathcal{m}_i \in \mathcal{M}$. The train and test subsets of $\mathcal{d}_{w,j}$ have a 80%/20% proportion.
#
# The performance $\epsilon[m_i, d_j, w]$ of each $\mathcal{m}_{i}^{\mathcal{d}_{w,j}}$ model is evaluated using the RMSE metric using the test subset of $\mathcal{d}_{w,j}$.
#
# ## Statistical Testing
#
# Given the mean $\mu_{m_i, d_j} = \frac{\sum_{w=1}^W \epsilon[m_i, d_j, w]}{W}$,  ANOVA aims to test the hypothesis:
#
# * $H_0$: The $\mu_{m_i, d_j}$ means are equal
# * $H_1$: At least one $\mu_{m_i, d_j}$ mean are not equal
#
# For the parametric ANOVA test, the F-test, some conditions must be respected:
#
# a) The samples must be independent and equaly distributed (i.i.d)
#
# b) The samples must be normally distributed;
#
# c) The samples must be homoskedastic (the variances must be equal)
#
# For the nonparametric tests there are no conditions.
#
# When the $H_0$ is rejected it means that the samples can be not equal, and therefore we need to compare all samples against themselves. This is called *post-hoc* tests.
#
# * $H_0$: $\mu_{m_a, d_j} < \mu_{m_b, d_j}$
# * $H_1$: $\mu_{m_a, d_j}\geq \mu_{m_b, d_j}$

# %% [markdown]
# ## Experiment Data

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_ht.csv', sep=',')
#df.head()
pd.set_option('display.max_rows', None)
df
# Out:
#          ds   model  window  avg_nrmse
# 0       AEC    KFTS       0      0.055
# 1       AEC    KFTS       1      0.045
# 2       AEC    KFTS       2      0.045
# 3       AEC    KFTS       3      0.049
# 4       AEC    KFTS       4      0.047
# 5       AEC    KFTS       5      0.044
# 6       AEC    KFTS       6      0.051
# 7       AEC    KFTS       7      0.044
# 8       AEC    KFTS       8      0.048
# 9       AEC    KFTS       9      0.053
# 10      AEC    KFTS      10      0.044
# 11      AEC    KFTS      11      0.045
# 12      AEC    KFTS      12      0.044
# 13      AEC    KFTS      13      0.049
# 14      AEC    KFTS      14      0.047
# 15      AEC    KFTS      15      0.052
# 16      AEC    KFTS      16      0.049
# 17      AEC    KFTS      17      0.037
# 18      AEC    KFTS      18      0.058
# 19      AEC    KFTS      19      0.049
# 20      AEC    KFTS      20      0.050
# 21      AEC    KFTS      21      0.045
# 22      AEC    KFTS      22      0.048
# 23      AEC    KFTS      23      0.047
# 24      AEC    KFTS      24      0.050
# 25      AEC    KFTS      25      0.062
# 26      AEC    KFTS      26      0.043
# 27      AEC    KFTS      27      0.054
# 28      AEC    KFTS      28      0.046
# 29      AEC    KFTS      29      0.048
# 30      AEC    PFTS       0      0.072
# 31      AEC    PFTS       1      0.070
# 32      AEC    PFTS       2      0.076
# 33      AEC    PFTS       3      0.062
# 34      AEC    PFTS       4      0.060
# 35      AEC    PFTS       5      0.066
# 36      AEC    PFTS       6      0.069
# 37      AEC    PFTS       7      0.062
# 38      AEC    PFTS       8      0.068
# 39      AEC    PFTS       9      0.071
# 40      AEC    PFTS      10      0.067
# 41      AEC    PFTS      11      0.067
# 42      AEC    PFTS      12      0.061
# 43      AEC    PFTS      13      0.073
# 44      AEC    PFTS      14      0.067
# 45      AEC    PFTS      15      0.068
# 46      AEC    PFTS      16      0.071
# 47      AEC    PFTS      17      0.052
# 48      AEC    PFTS      18      0.072
# 49      AEC    PFTS      19      0.067
# 50      AEC    PFTS      20      0.069
# 51      AEC    PFTS      21      0.062
# 52      AEC    PFTS      22      0.065
# 53      AEC    PFTS      23      0.070
# 54      AEC    PFTS      24      0.074
# 55      AEC    PFTS      25      0.082
# 56      AEC    PFTS      26      0.069
# 57      AEC    PFTS      27      0.082
# 58      AEC    PFTS      28      0.059
# 59      AEC    PFTS      29      0.065
# 60      AEC     VAR       0      0.071
# 61      AEC     VAR       1      0.058
# 62      AEC     VAR       2      0.117
# 63      AEC     VAR       3      0.148
# 64      AEC     VAR       4      0.056
# 65      AEC     VAR       5      0.071
# 66      AEC     VAR       6      0.061
# 67      AEC     VAR       7      0.064
# 68      AEC     VAR       8      0.091
# 69      AEC     VAR       9      0.073
# 70      AEC     VAR      10      0.080
# 71      AEC     VAR      11      0.084
# 72      AEC     VAR      12      0.083
# 73      AEC     VAR      13      0.084
# 74      AEC     VAR      14      0.074
# 75      AEC     VAR      15      0.092
# 76      AEC     VAR      16      0.103
# 77      AEC     VAR      17      0.152
# 78      AEC     VAR      18      0.080
# 79      AEC     VAR      19      0.075
# 80      AEC     VAR      20      0.063
# 81      AEC     VAR      21      0.056
# 82      AEC     VAR      22      0.121
# 83      AEC     VAR      23      0.207
# 84      AEC     VAR      24      0.068
# 85      AEC     VAR      25      0.060
# 86      AEC     VAR      26      0.053
# 87      AEC     VAR      27      0.113
# 88      AEC     VAR      28      0.114
# 89      AEC     VAR      29      0.089
# 90      AEC   SLSTM       0      0.218
# 91      AEC   SLSTM       1      0.265
# 92      AEC   SLSTM       2      0.582
# 93      AEC   SLSTM       3      0.382
# 94      AEC   SLSTM       4      0.262
# 95      AEC   SLSTM       5      0.211
# 96      AEC   SLSTM       6      0.177
# 97      AEC   SLSTM       7      0.220
# 98      AEC   SLSTM       8      0.406
# 99      AEC   SLSTM       9      0.235
# 100     AEC   SLSTM      10      0.209
# 101     AEC   SLSTM      11      0.242
# 102     AEC   SLSTM      12      0.225
# 103     AEC   SLSTM      13      0.291
# 104     AEC   SLSTM      14      0.224
# 105     AEC   SLSTM      15      0.198
# 106     AEC   SLSTM      16      0.221
# 107     AEC   SLSTM      17      0.340
# 108     AEC   SLSTM      18      0.255
# 109     AEC   SLSTM      19      0.222
# 110     AEC   SLSTM      20      0.211
# 111     AEC   SLSTM      21      0.182
# 112     AEC   SLSTM      22      0.230
# 113     AEC   SLSTM      23      0.439
# 114     AEC   SLSTM      24      0.257
# 115     AEC   SLSTM      25      0.246
# 116     AEC   SLSTM      26      0.186
# 117     AEC   SLSTM      27      0.320
# 118     AEC   SLSTM      28      0.376
# 119     AEC   SLSTM      29      0.260
# 120     AEC    LSTM       0      0.191
# 121     AEC    LSTM       1      0.187
# 122     AEC    LSTM       2      0.228
# 123     AEC    LSTM       3      0.209
# 124     AEC    LSTM       4      0.171
# 125     AEC    LSTM       5      0.167
# 126     AEC    LSTM       6      0.173
# 127     AEC    LSTM       7      0.149
# 128     AEC    LSTM       8      0.203
# 129     AEC    LSTM       9      0.183
# 130     AEC    LSTM      10      0.179
# 131     AEC    LSTM      11      0.158
# 132     AEC    LSTM      12      0.181
# 133     AEC    LSTM      13      0.148
# 134     AEC    LSTM      14      0.184
# 135     AEC    LSTM      15      0.151
# 136     AEC    LSTM      16      0.147
# 137     AEC    LSTM      17      0.197
# 138     AEC    LSTM      18      0.191
# 139     AEC    LSTM      19      0.166
# 140     AEC    LSTM      20      0.159
# 141     AEC    LSTM      21      0.168
# 142     AEC    LSTM      22      0.187
# 143     AEC    LSTM      23      0.185
# 144     AEC    LSTM      24      0.142
# 145     AEC    LSTM      25      0.171
# 146     AEC    LSTM      26      0.180
# 147     AEC    LSTM      27      0.190
# 148     AEC    LSTM      28      0.195
# 149     AEC    LSTM      29      0.160
# 150     AEC     GRU       0      0.179
# 151     AEC     GRU       1      0.179
# 152     AEC     GRU       2      0.219
# 153     AEC     GRU       3      0.184
# 154     AEC     GRU       4      0.168
# 155     AEC     GRU       5      0.166
# 156     AEC     GRU       6      0.161
# 157     AEC     GRU       7      0.139
# 158     AEC     GRU       8      0.185
# 159     AEC     GRU       9      0.176
# 160     AEC     GRU      10      0.172
# 161     AEC     GRU      11      0.148
# 162     AEC     GRU      12      0.167
# 163     AEC     GRU      13      0.138
# 164     AEC     GRU      14      0.173
# 165     AEC     GRU      15      0.143
# 166     AEC     GRU      16      0.135
# 167     AEC     GRU      17      0.175
# 168     AEC     GRU      18      0.176
# 169     AEC     GRU      19      0.155
# 170     AEC     GRU      20      0.143
# 171     AEC     GRU      21      0.146
# 172     AEC     GRU      22      0.160
# 173     AEC     GRU      23      0.166
# 174     AEC     GRU      24      0.138
# 175     AEC     GRU      25      0.154
# 176     AEC     GRU      26      0.161
# 177     AEC     GRU      27      0.180
# 178     AEC     GRU      28      0.169
# 179     AEC     GRU      29      0.146
# 180     AEC     RNN       0      0.187
# 181     AEC     RNN       1      0.180
# 182     AEC     RNN       2      0.214
# 183     AEC     RNN       3      0.196
# 184     AEC     RNN       4      0.163
# 185     AEC     RNN       5      0.161
# 186     AEC     RNN       6      0.161
# 187     AEC     RNN       7      0.140
# 188     AEC     RNN       8      0.197
# 189     AEC     RNN       9      0.170
# 190     AEC     RNN      10      0.172
# 191     AEC     RNN      11      0.139
# 192     AEC     RNN      12      0.171
# 193     AEC     RNN      13      0.139
# 194     AEC     RNN      14      0.181
# 195     AEC     RNN      15      0.142
# 196     AEC     RNN      16      0.139
# 197     AEC     RNN      17      0.169
# 198     AEC     RNN      18      0.173
# 199     AEC     RNN      19      0.153
# 200     AEC     RNN      20      0.145
# 201     AEC     RNN      21      0.153
# 202     AEC     RNN      22      0.170
# 203     AEC     RNN      23      0.180
# 204     AEC     RNN      24      0.144
# 205     AEC     RNN      25      0.158
# 206     AEC     RNN      26      0.167
# 207     AEC     RNN      27      0.177
# 208     AEC     RNN      28      0.167
# 209     AEC     RNN      29      0.155
# 210     AEC      RF       0      0.128
# 211     AEC      RF       1      0.146
# 212     AEC      RF       2      0.262
# 213     AEC      RF       3      0.232
# 214     AEC      RF       4      0.090
# 215     AEC      RF       5      0.119
# 216     AEC      RF       6      0.100
# 217     AEC      RF       7      0.165
# 218     AEC      RF       8      0.276
# 219     AEC      RF       9      0.095
# 220     AEC      RF      10      0.084
# 221     AEC      RF      11      0.117
# 222     AEC      RF      12      0.099
# 223     AEC      RF      13      0.096
# 224     AEC      RF      14      0.097
# 225     AEC      RF      15      0.090
# 226     AEC      RF      16      0.111
# 227     AEC      RF      17      0.162
# 228     AEC      RF      18      0.121
# 229     AEC      RF      19      0.084
# 230     AEC      RF      20      0.105
# 231     AEC      RF      21      0.099
# 232     AEC      RF      22      0.152
# 233     AEC      RF      23      0.114
# 234     AEC      RF      24      0.111
# 235     AEC      RF      25      0.201
# 236     AEC      RF      26      0.108
# 237     AEC      RF      27      0.156
# 238     AEC      RF      28      0.283
# 239     AEC      RF      29      0.137
# 240     AEC     SVR       0      0.349
# 241     AEC     SVR       1      0.338
# 242     AEC     SVR       2      0.884
# 243     AEC     SVR       3      0.659
# 244     AEC     SVR       4      0.255
# 245     AEC     SVR       5      0.297
# 246     AEC     SVR       6      0.244
# 247     AEC     SVR       7      0.408
# 248     AEC     SVR       8      0.868
# 249     AEC     SVR       9      0.270
# 250     AEC     SVR      10      0.264
# 251     AEC     SVR      11      0.292
# 252     AEC     SVR      12      0.313
# 253     AEC     SVR      13      0.345
# 254     AEC     SVR      14      0.273
# 255     AEC     SVR      15      0.214
# 256     AEC     SVR      16      0.298
# 257     AEC     SVR      17      0.623
# 258     AEC     SVR      18      0.287
# 259     AEC     SVR      19      0.266
# 260     AEC     SVR      20      0.248
# 261     AEC     SVR      21      0.270
# 262     AEC     SVR      22      0.394
# 263     AEC     SVR      23      0.501
# 264     AEC     SVR      24      0.360
# 265     AEC     SVR      25      0.376
# 266     AEC     SVR      26      0.242
# 267     AEC     SVR      27      0.461
# 268     AEC     SVR      28      0.640
# 269     AEC     SVR      29      0.349
# 270     AEC  SLSTM2       0      0.256
# 271     AEC  SLSTM2       1      0.285
# 272     AEC  SLSTM2       2      0.619
# 273     AEC  SLSTM2       3      0.420
# 274     AEC  SLSTM2       4      0.298
# 275     AEC  SLSTM2       5      0.240
# 276     AEC  SLSTM2       6      0.195
# 277     AEC  SLSTM2       7      0.254
# 278     AEC  SLSTM2       8      0.425
# 279     AEC  SLSTM2       9      0.252
# 280     AEC  SLSTM2      10      0.236
# 281     AEC  SLSTM2      11      0.265
# 361     KSH     VAR       1      0.033
# 362     KSH     VAR       2      0.403
# 363     KSH     VAR       3      0.046
# 364     KSH     VAR       4      0.028
# 365     KSH     VAR       5      0.029
# 366     KSH     VAR       6      0.036
# 367     KSH     VAR       7      0.031
# 368     KSH     VAR       8      0.035
# 369     KSH     VAR       9      0.027
# 370     KSH     VAR      10      0.032
# 371     KSH     VAR      11      0.045
# 372     KSH     VAR      12      1.074
# 373     KSH     VAR      13      0.050
# 374     KSH     VAR      14      0.075
# 375     KSH     VAR      15      0.048
# 376     KSH     VAR      16      0.029
# 377     KSH     VAR      17      0.037
# 378     KSH     VAR      18      0.036
# 379     KSH     VAR      19      0.079
# 380     KSH     VAR      20      0.108
# 381     KSH     VAR      21      0.034
# 382     KSH     VAR      22      0.032
# 383     KSH     VAR      23      0.028
# 384     KSH     VAR      24      0.031
# 385     KSH     VAR      25      0.029
# 386     KSH     VAR      26      0.056
# 387     KSH     VAR      27      0.039
# 388     KSH     VAR      28      0.043
# 389     KSH     VAR      29      0.063
# 390     KSH   SLSTM       0      0.170
# 391     KSH   SLSTM       1      0.056
# 392     KSH   SLSTM       2      0.387
# 393     KSH   SLSTM       3      0.074
# 394     KSH   SLSTM       4      0.042
# 395     KSH   SLSTM       5      0.052
# 396     KSH   SLSTM       6      0.045
# 397     KSH   SLSTM       7      0.055
# 398     KSH   SLSTM       8      0.110
# 399     KSH   SLSTM       9      0.054
# 400     KSH   SLSTM      10      0.072
# 401     KSH   SLSTM      11      0.075
# 402     KSH   SLSTM      12      7.496
# 403     KSH   SLSTM      13      0.124
# 404     KSH   SLSTM      14      0.096
# 405     KSH   SLSTM      15      0.068
# 406     KSH   SLSTM      16      0.067
# 407     KSH   SLSTM      17      0.156
# 408     KSH   SLSTM      18      0.059
# 409     KSH   SLSTM      19      0.095
# 410     KSH   SLSTM      20      0.098
# 411     KSH   SLSTM      21      0.059
# 412     KSH   SLSTM      22      0.041
# 413     KSH   SLSTM      23      0.042
# 414     KSH   SLSTM      24      0.066
# 415     KSH   SLSTM      25      0.075
# 416     KSH   SLSTM      26      0.155
# 417     KSH   SLSTM      27      0.067
# 418     KSH   SLSTM      28      0.054
# 419     KSH   SLSTM      29      0.111
# 420     KSH    LSTM       0      0.067
# 421     KSH    LSTM       1      0.070
# 422     KSH    LSTM       2      0.080
# 423     KSH    LSTM       3      0.066
# 424     KSH    LSTM       4      0.059
# 425     KSH    LSTM       5      0.080
# 426     KSH    LSTM       6      0.066
# 427     KSH    LSTM       7      0.060
# 428     KSH    LSTM       8      0.077
# 429     KSH    LSTM       9      0.060
# 430     KSH    LSTM      10      0.053
# 431     KSH    LSTM      11      0.071
# 432     KSH    LSTM      12      0.148
# 433     KSH    LSTM      13      0.074
# 434     KSH    LSTM      14      0.068
# 435     KSH    LSTM      15      0.071
# 436     KSH    LSTM      16      0.057
# 437     KSH    LSTM      17      0.067
# 438     KSH    LSTM      18      0.073
# 439     KSH    LSTM      19      0.066
# 440     KSH    LSTM      20      0.084
# 441     KSH    LSTM      21      0.055
# 442     KSH    LSTM      22      0.048
# 443     KSH    LSTM      23      0.052
# 444     KSH    LSTM      24      0.068
# 445     KSH    LSTM      25      0.063
# 446     KSH    LSTM      26      0.063
# 447     KSH    LSTM      27      0.080
# 448     KSH    LSTM      28      0.073
# 449     KSH    LSTM      29      0.085
# 450     KSH     GRU       0      0.063
# 451     KSH     GRU       1      0.055
# 452     KSH     GRU       2      0.062
# 453     KSH     GRU       3      0.056
# 454     KSH     GRU       4      0.043
# 455     KSH     GRU       5      0.053
# 456     KSH     GRU       6      0.054
# 457     KSH     GRU       7      0.056
# 458     KSH     GRU       8      0.065
# 459     KSH     GRU       9      0.047
# 460     KSH     GRU      10      0.050
# 461     KSH     GRU      11      0.095
# 462     KSH     GRU      12      0.137
# 463     KSH     GRU      13      0.054
# 464     KSH     GRU      14      0.059
# 465     KSH     GRU      15      0.067
# 466     KSH     GRU      16      0.052
# 467     KSH     GRU      17      0.065
# 468     KSH     GRU      18      0.057
# 469     KSH     GRU      19      0.057
# 470     KSH     GRU      20      0.057
# 471     KSH     GRU      21      0.054
# 472     KSH     GRU      22      0.043
# 473     KSH     GRU      23      0.050
# 474     KSH     GRU      24      0.259
# 475     KSH     GRU      25      0.053
# 476     KSH     GRU      26      0.053
# 477     KSH     GRU      27      0.063
# 478     KSH     GRU      28      0.061
# 479     KSH     GRU      29      0.066
# 480     KSH     RNN       0      0.051
# 481     KSH     RNN       1      0.048
# 482     KSH     RNN       2      0.048
# 483     KSH     RNN       3      0.045
# 484     KSH     RNN       4      0.039
# 485     KSH     RNN       5      0.040
# 486     KSH     RNN       6      0.045
# 487     KSH     RNN       7      0.045
# 488     KSH     RNN       8      0.052
# 489     KSH     RNN       9      0.037
# 490     KSH     RNN      10      0.040
# 491     KSH     RNN      11      0.040
# 492     KSH     RNN      12      0.073
# 493     KSH     RNN      13      0.040
# 494     KSH     RNN      14      0.038
# 495     KSH     RNN      15      0.043
# 496     KSH     RNN      16      0.039
# 497     KSH     RNN      17      0.050
# 498     KSH     RNN      18      0.045
# 499     KSH     RNN      19      0.044
# 500     KSH     RNN      20      0.046
# 501     KSH     RNN      21      0.042
# 502     KSH     RNN      22      0.037
# 503     KSH     RNN      23      0.036
# 504     KSH     RNN      24      0.044
# 505     KSH     RNN      25      0.040
# 506     KSH     RNN      26      0.036
# 507     KSH     RNN      27      0.055
# 508     KSH     RNN      28      0.052
# 509     KSH     RNN      29      0.055
# 510     KSH      RF       0      0.084
# 511     KSH      RF       1      0.039
# 512     KSH      RF       2      0.086
# 513     KSH      RF       3      0.050
# 514     KSH      RF       4      0.031
# 515     KSH      RF       5      0.046
# 516     KSH      RF       6      0.043
# 517     KSH      RF       7      0.062
# 518     KSH      RF       8      0.066
# 519     KSH      RF       9      0.033
# 520     KSH      RF      10      0.053
# 521     KSH      RF      11      0.069
# 522     KSH      RF      12      0.396
# 523     KSH      RF      13      0.085
# 524     KSH      RF      14      0.062
# 525     KSH      RF      15      0.099
# 526     KSH      RF      16      0.036
# 527     KSH      RF      17      0.064
# 528     KSH      RF      18      0.040
# 529     KSH      RF      19      0.066
# 530     KSH      RF      20      0.067
# 531     KSH      RF      21      0.038
# 532     KSH      RF      22      0.041
# 533     KSH      RF      23      0.034
# 534     KSH      RF      24      0.054
# 535     KSH      RF      25      0.039
# 536     KSH      RF      26      0.054
# 537     KSH      RF      27      0.050
# 538     KSH      RF      28      0.057
# 539     KSH      RF      29      0.050
# 540     KSH     SVR       0      0.176
# 541     KSH     SVR       1      0.094
# 542     KSH     SVR       2      0.756
# 543     KSH     SVR       3      0.123
# 544     KSH     SVR       4      0.081
# 545     KSH     SVR       5      0.108
# 546     KSH     SVR       6      0.070
# 547     KSH     SVR       7      0.126
# 548     KSH     SVR       8      0.307
# 549     KSH     SVR       9      0.093
# 550     KSH     SVR      10      0.200
# 551     KSH     SVR      11      0.138
# 552     KSH     SVR      12     26.457
# 553     KSH     SVR      13      0.292
# 554     KSH     SVR      14      0.212
# 555     KSH     SVR      15      0.108
# 556     KSH     SVR      16      0.131
# 557     KSH     SVR      17      0.415
# 558     KSH     SVR      18      0.110
# 559     KSH     SVR      19      0.266
# 560     KSH     SVR      20      0.243
# 561     KSH     SVR      21      0.098
# 562     KSH     SVR      22      0.073
# 563     KSH     SVR      23      0.096
# 564     KSH     SVR      24      0.120
# 565     KSH     SVR      25      0.277
# 566     KSH     SVR      26      0.382
# 567     KSH     SVR      27      0.117
# 568     KSH     SVR      28      0.105
# 569     KSH     SVR      29      0.286
# 570     KSH  SLSTM2       0      0.162
# 571     KSH  SLSTM2       1      0.068
# 572     KSH  SLSTM2       2      0.394
# 573     KSH  SLSTM2       3      0.071
# 574     KSH  SLSTM2       4      0.043
# 575     KSH  SLSTM2       5      0.054
# 576     KSH  SLSTM2       6      0.047
# 577     KSH  SLSTM2       7      0.063
# 578     KSH  SLSTM2       8      0.106
# 579     KSH  SLSTM2       9      0.058
# 580     KSH  SLSTM2      10      0.089
# 581     KSH  SLSTM2      11      0.059
# 582     KSH  SLSTM2      12     11.215
# 583     KSH  SLSTM2      13      0.117
# 584     KSH  SLSTM2      14      0.090
# 585     KSH  SLSTM2      15      0.056
# 586     KSH  SLSTM2      16      0.069
# 587     KSH  SLSTM2      17      0.182
# 588     KSH  SLSTM2      18      0.059
# 589     KSH  SLSTM2      19      0.110
# 590     KSH  SLSTM2      20      0.119
# 591     KSH  SLSTM2      21      0.060
# 592     KSH  SLSTM2      22      0.044
# 593     KSH  SLSTM2      23      0.045
# 594     KSH  SLSTM2      24      0.074
# 595     KSH  SLSTM2      25      0.078
# 596     KSH  SLSTM2      26      0.163
# 597     KSH  SLSTM2      27      0.069
# 598     KSH  SLSTM2      28      0.058
# 599     KSH  SLSTM2      29      0.113
# 600     AQI    KFTS       0      0.148
# 601     AQI    KFTS       1      0.148
# 602     AQI    KFTS       2      0.173
# 603     AQI    KFTS       3      0.146
# 604     AQI    KFTS       4      0.151
# 605     AQI    KFTS       5      0.166
# 606     AQI    KFTS       6      0.134
# 607     AQI    KFTS       7      0.144
# 608     AQI    KFTS       8      0.143
# 609     AQI    KFTS       9      0.161
# 692     AQI   SLSTM       2      0.396
# 693     AQI   SLSTM       3      0.148
# 694     AQI   SLSTM       4      0.135
# 695     AQI   SLSTM       5      0.378
# 696     AQI   SLSTM       6      0.137
# 697     AQI   SLSTM       7      0.452
# 698     AQI   SLSTM       8      0.121
# 699     AQI   SLSTM       9      0.138
# 700     AQI   SLSTM      10      0.126
# 701     AQI   SLSTM      11      0.203
# 702     AQI   SLSTM      12      0.136
# 703     AQI   SLSTM      13      0.155
# 704     AQI   SLSTM      14      0.389
# 705     AQI   SLSTM      15      0.132
# 706     AQI   SLSTM      16      0.140
# 707     AQI   SLSTM      17      0.143
# 708     AQI   SLSTM      18      0.250
# 709     AQI   SLSTM      19      0.133
# 710     AQI   SLSTM      20      0.122
# 711     AQI   SLSTM      21      0.129
# 712     AQI   SLSTM      22      0.425
# 713     AQI   SLSTM      23      0.797
# 714     AQI   SLSTM      24      0.129
# 715     AQI   SLSTM      25      0.111
# 716     AQI   SLSTM      26      0.923
# 717     AQI   SLSTM      27      0.114
# 718     AQI   SLSTM      28      0.178
# 719     AQI   SLSTM      29      0.147
# 720     AQI    LSTM       0      0.150
# 721     AQI    LSTM       1      0.221
# 722     AQI    LSTM       2      0.188
# 723     AQI    LSTM       3      0.153
# 724     AQI    LSTM       4      0.137
# 725     AQI    LSTM       5      0.272
# 726     AQI    LSTM       6      0.139
# 727     AQI    LSTM       7      0.256
# 728     AQI    LSTM       8      0.126
# 729     AQI    LSTM       9      0.133
# 730     AQI    LSTM      10      0.131
# 731     AQI    LSTM      11      0.168
# 732     AQI    LSTM      12      0.215
# 733     AQI    LSTM      13      0.223
# 734     AQI    LSTM      14      0.152
# 735     AQI    LSTM      15      0.134
# 736     AQI    LSTM      16      0.172
# 737     AQI    LSTM      17      0.147
# 738     AQI    LSTM      18      0.150
# 739     AQI    LSTM      19      0.130
# 740     AQI    LSTM      20      0.133
# 741     AQI    LSTM      21      0.186
# 742     AQI    LSTM      22      0.191
# 743     AQI    LSTM      23      0.177
# 744     AQI    LSTM      24      0.224
# 745     AQI    LSTM      25      0.166
# 746     AQI    LSTM      26      0.149
# 747     AQI    LSTM      27      0.138
# 748     AQI    LSTM      28      0.147
# 749     AQI    LSTM      29      0.135
# 750     AQI     GRU       0      0.136
# 751     AQI     GRU       1      0.222
# 752     AQI     GRU       2      0.183
# 753     AQI     GRU       3      0.144
# 754     AQI     GRU       4      0.133
# 755     AQI     GRU       5      0.255
# 756     AQI     GRU       6      0.134
# 757     AQI     GRU       7      0.228
# 758     AQI     GRU       8      0.118
# 759     AQI     GRU       9      0.125
# 760     AQI     GRU      10      0.127
# 761     AQI     GRU      11      0.167
# 762     AQI     GRU      12      0.206
# 763     AQI     GRU      13      0.212
# 764     AQI     GRU      14      0.145
# 765     AQI     GRU      15      0.129
# 766     AQI     GRU      16      0.163
# 767     AQI     GRU      17      0.141
# 768     AQI     GRU      18      0.144
# 769     AQI     GRU      19      0.122
# 770     AQI     GRU      20      0.127
# 771     AQI     GRU      21      0.180
# 772     AQI     GRU      22      0.176
# 773     AQI     GRU      23      0.175
# 774     AQI     GRU      24      0.215
# 775     AQI     GRU      25      0.164
# 776     AQI     GRU      26      0.147
# 777     AQI     GRU      27      0.127
# 778     AQI     GRU      28      0.143
# 779     AQI     GRU      29      0.127
# 780     AQI     RNN       0      0.136
# 781     AQI     RNN       1      0.221
# 782     AQI     RNN       2      0.192
# 783     AQI     RNN       3      0.149
# 784     AQI     RNN       4      0.141
# 785     AQI     RNN       5      0.271
# 786     AQI     RNN       6      0.136
# 787     AQI     RNN       7      0.245
# 788     AQI     RNN       8      0.117
# 789     AQI     RNN       9      0.128
# 790     AQI     RNN      10      0.136
# 791     AQI     RNN      11      0.165
# 792     AQI     RNN      12      0.217
# 793     AQI     RNN      13      0.218
# 794     AQI     RNN      14      0.154
# 795     AQI     RNN      15      0.131
# 796     AQI     RNN      16      0.167
# 797     AQI     RNN      17      0.137
# 798     AQI     RNN      18      0.145
# 799     AQI     RNN      19      0.118
# 800     AQI     RNN      20      0.126
# 801     AQI     RNN      21      0.182
# 802     AQI     RNN      22      0.187
# 803     AQI     RNN      23      0.176
# 804     AQI     RNN      24      0.187
# 805     AQI     RNN      25      0.157
# 806     AQI     RNN      26      0.151
# 807     AQI     RNN      27      0.129
# 808     AQI     RNN      28      0.154
# 809     AQI     RNN      29      0.117
# 810     AQI      RF       0      0.128
# 811     AQI      RF       1      3.538
# 812     AQI      RF       2      0.286
# 813     AQI      RF       3      0.139
# 814     AQI      RF       4      0.137
# 815     AQI      RF       5      0.333
# 816     AQI      RF       6      0.135
# 817     AQI      RF       7      0.432
# 818     AQI      RF       8      0.116
# 819     AQI      RF       9      0.135
# 820     AQI      RF      10      0.123
# 821     AQI      RF      11      0.955
# 822     AQI      RF      12      0.138
# 823     AQI      RF      13      0.195
# 824     AQI      RF      14      2.408
# 825     AQI      RF      15      0.135
# 826     AQI      RF      16      0.148
# 827     AQI      RF      17      0.127
# 828     AQI      RF      18      0.194
# 829     AQI      RF      19      0.137
# 830     AQI      RF      20      0.122
# 831     AQI      RF      21      0.122
# 832     AQI      RF      22      1.159
# 833     AQI      RF      23     14.167
# 834     AQI      RF      24      0.125
# 835     AQI      RF      25      0.150
# 836     AQI      RF      26      0.261
# 837     AQI      RF      27      0.114
# 838     AQI      RF      28      0.169
# 839     AQI      RF      29      0.148
# 840     AQI     SVR       0      0.145
# 841     AQI     SVR       1      3.285
# 842     AQI     SVR       2      0.251
# 843     AQI     SVR       3      0.176
# 844     AQI     SVR       4      0.154
# 845     AQI     SVR       5      0.385
# 846     AQI     SVR       6      0.136
# 847     AQI     SVR       7      0.463
# 848     AQI     SVR       8      0.110
# 849     AQI     SVR       9      0.149
# 850     AQI     SVR      10      0.132
# 851     AQI     SVR      11      0.133
# 852     AQI     SVR      12      0.148
# 853     AQI     SVR      13      0.148
# 854     AQI     SVR      14      0.182
# 855     AQI     SVR      15      0.168
# 856     AQI     SVR      16      0.247
# 857     AQI     SVR      17      0.149
# 858     AQI     SVR      18      0.325
# 859     AQI     SVR      19      0.161
# 860     AQI     SVR      20      0.139
# 861     AQI     SVR      21      0.122
# 862     AQI     SVR      22      0.172
# 863     AQI     SVR      23      0.257
# 864     AQI     SVR      24      0.124
# 865     AQI     SVR      25      0.147
# 866     AQI     SVR      26      0.303
# 867     AQI     SVR      27      0.126
# 868     AQI     SVR      28      0.114
# 869     AQI     SVR      29      0.326
# 870     AQI  SLSTM2       0      0.143
# 871     AQI  SLSTM2       1      0.619
# 872     AQI  SLSTM2       2      0.375
# 873     AQI  SLSTM2       3      0.160
# 874     AQI  SLSTM2       4      0.134
# 875     AQI  SLSTM2       5      0.390
# 876     AQI  SLSTM2       6      0.139
# 877     AQI  SLSTM2       7      0.448
# 878     AQI  SLSTM2       8      0.122
# 879     AQI  SLSTM2       9      0.138
# 880     AQI  SLSTM2      10      0.129
# 881     AQI  SLSTM2      11      0.327
# 882     AQI  SLSTM2      12      0.138
# 883     AQI  SLSTM2      13      0.174
# 884     AQI  SLSTM2      14      0.379
# 885     AQI  SLSTM2      15      0.134
# 886     AQI  SLSTM2      16      0.144
# 887     AQI  SLSTM2      17      0.149
# 888     AQI  SLSTM2      18      0.263
# 889     AQI  SLSTM2      19      0.136
# 890     AQI  SLSTM2      20      0.129
# 891     AQI  SLSTM2      21      0.130
# 892     AQI  SLSTM2      22      0.638
# 893     AQI  SLSTM2      23      0.841
# 894     AQI  SLSTM2      24      0.131
# 895     AQI  SLSTM2      25      0.111
# 896     AQI  SLSTM2      26      1.287
# 897     AQI  SLSTM2      27      0.116
# 898     AQI  SLSTM2      28      0.193
# 899     AQI  SLSTM2      29      0.151
# 900    AQB1    KFTS       0      0.097
# 901    AQB1    KFTS       1      0.074
# 902    AQB1    KFTS       2      0.103
# 903    AQB1    KFTS       3      0.089
# 904    AQB1    KFTS       4      0.128
# 905    AQB1    KFTS       5      0.080
# 906    AQB1    KFTS       6      0.083
# 907    AQB1    KFTS       7      0.083
# 908    AQB1    KFTS       8      0.084
# 909    AQB1    KFTS       9      0.091
# 910    AQB1    KFTS      10      0.100
# 911    AQB1    KFTS      11      0.077
# 912    AQB1    KFTS      12      0.086
# 913    AQB1    KFTS      13      0.094
# 914    AQB1    KFTS      14      0.086
# 915    AQB1    KFTS      15      0.086
# 916    AQB1    KFTS      16      0.079
# 917    AQB1    KFTS      17      0.093
# 918    AQB1    KFTS      18      0.080
# 919    AQB1    KFTS      19      0.068
# 920    AQB1    KFTS      20      0.081
# 921    AQB1    KFTS      21      0.073
# 922    AQB1    KFTS      22      0.076
# 923    AQB1    KFTS      23      0.085
# 924    AQB1    KFTS      24      0.093
# 925    AQB1    KFTS      25      0.085
# 926    AQB1    KFTS      26      0.134
# 927    AQB1    KFTS      27      0.133
# 928    AQB1    KFTS      28      0.099
# 929    AQB1    KFTS      29      0.105
# 930    AQB1    PFTS       0      0.107
# 931    AQB1    PFTS       1      0.118
# 932    AQB1    PFTS       2      0.128
# 933    AQB1    PFTS       3      0.127
# 934    AQB1    PFTS       4      0.201
# 935    AQB1    PFTS       5      0.132
# 936    AQB1    PFTS       6      0.104
# 937    AQB1    PFTS       7      0.106
# 1478   AQB6  SLSTM2       8      0.150
# 1479   AQB6  SLSTM2       9      0.146
# 1480   AQB6  SLSTM2      10      0.126
# 1481   AQB6  SLSTM2      11      0.133
# 1482   AQB6  SLSTM2      12      0.153
# 1483   AQB6  SLSTM2      13      0.123
# 1484   AQB6  SLSTM2      14      0.115
# 1485   AQB6  SLSTM2      15      0.133
# 1486   AQB6  SLSTM2      16      0.146
# 1487   AQB6  SLSTM2      17      0.122
# 1488   AQB6  SLSTM2      18      0.210
# 1489   AQB6  SLSTM2      19      0.110
# 1490   AQB6  SLSTM2      20      0.142
# 1491   AQB6  SLSTM2      21      0.130
# 1492   AQB6  SLSTM2      22      0.118
# 1493   AQB6  SLSTM2      23      0.141
# 1494   AQB6  SLSTM2      24      0.130
# 1495   AQB6  SLSTM2      25      0.220
# 1496   AQB6  SLSTM2      26      8.039
# 1497   AQB6  SLSTM2      27      0.111
# 1498   AQB6  SLSTM2      28      0.153
# 1499   AQB6  SLSTM2      29      0.835
# 1500  AQB12    KFTS       0      0.125
# 1501  AQB12    KFTS       1      0.114
# 1502  AQB12    KFTS       2      0.104
# 1503  AQB12    KFTS       3      0.093
# 1504  AQB12    KFTS       4      0.106
# 1505  AQB12    KFTS       5      0.127
# 1506  AQB12    KFTS       6      0.110
# 1507  AQB12    KFTS       7      0.111
# 1508  AQB12    KFTS       8      0.113
# 1509  AQB12    KFTS       9      0.128
# 1510  AQB12    KFTS      10      0.125
# 1511  AQB12    KFTS      11      0.108
# 1512  AQB12    KFTS      12      0.103
# 1513  AQB12    KFTS      13      0.113
# 1514  AQB12    KFTS      14      0.107
# 1515  AQB12    KFTS      15      0.131
# 1516  AQB12    KFTS      16      0.102
# 1517  AQB12    KFTS      17      0.084
# 1518  AQB12    KFTS      18      0.090
# 1519  AQB12    KFTS      19      0.100
# 1520  AQB12    KFTS      20      0.103
# 1521  AQB12    KFTS      21      0.106
# 1522  AQB12    KFTS      22      0.107
# 1523  AQB12    KFTS      23      0.124
# 1524  AQB12    KFTS      24      0.101
# 1525  AQB12    KFTS      25      0.114
# 1526  AQB12    KFTS      26      0.096
# 1527  AQB12    KFTS      27      0.101
# 1528  AQB12    KFTS      28      0.113
# 1529  AQB12    KFTS      29      0.113
# 1530  AQB12    PFTS       0      0.128
# 1531  AQB12    PFTS       1      0.128
# 1532  AQB12    PFTS       2      0.158
# 1533  AQB12    PFTS       3      0.131
# 1534  AQB12    PFTS       4      0.112
# 1535  AQB12    PFTS       5      0.148
# 1536  AQB12    PFTS       6      0.131
# 1537  AQB12    PFTS       7      0.125
# 1538  AQB12    PFTS       8      0.135
# 1539  AQB12    PFTS       9      0.134
# 1540  AQB12    PFTS      10      0.174
# 1541  AQB12    PFTS      11      0.122
# 1542  AQB12    PFTS      12      0.112
# 1543  AQB12    PFTS      13      0.117
# 1544  AQB12    PFTS      14      0.119
# 1545  AQB12    PFTS      15      0.135
# 1546  AQB12    PFTS      16      0.122
# 1547  AQB12    PFTS      17      0.092
# 1548  AQB12    PFTS      18      0.097
# 1623  AQB12    LSTM       3      0.210
# 1624  AQB12    LSTM       4      0.194
# 1625  AQB12    LSTM       5      0.184
# 1626  AQB12    LSTM       6      0.198
# 1627  AQB12    LSTM       7      0.189
# 1628  AQB12    LSTM       8      0.202
# 1629  AQB12    LSTM       9      0.202
# 1630  AQB12    LSTM      10      0.192
# 1631  AQB12    LSTM      11      0.189
# 1632  AQB12    LSTM      12      0.176
# 1633  AQB12    LSTM      13      0.188
# 1634  AQB12    LSTM      14      0.164
# 1635  AQB12    LSTM      15      0.177
# 1636  AQB12    LSTM      16      0.182
# 1637  AQB12    LSTM      17      0.168
# 1638  AQB12    LSTM      18      0.211
# 1639  AQB12    LSTM      19      0.180
# 1640  AQB12    LSTM      20      0.201
# 1641  AQB12    LSTM      21      0.174
# 1642  AQB12    LSTM      22      0.177
# 1643  AQB12    LSTM      23      0.183
# 1644  AQB12    LSTM      24      0.187
# 1645  AQB12    LSTM      25      0.176
# 1646  AQB12    LSTM      26      0.188
# 1647  AQB12    LSTM      27      0.185
# 1648  AQB12    LSTM      28      0.192
# 1649  AQB12    LSTM      29      0.203
# 1650  AQB12     GRU       0      0.166
# 1651  AQB12     GRU       1      0.205
# 1652  AQB12     GRU       2      0.219
# 1653  AQB12     GRU       3      0.207
# 1654  AQB12     GRU       4      0.186
# 1655  AQB12     GRU       5      0.192
# 1656  AQB12     GRU       6      0.199
# 1657  AQB12     GRU       7      0.178
# 1658  AQB12     GRU       8      0.193
# 1659  AQB12     GRU       9      0.185
# 1660  AQB12     GRU      10      0.184
# 1661  AQB12     GRU      11      0.185
# 1662  AQB12     GRU      12      0.177
# 1663  AQB12     GRU      13      0.189
# 1664  AQB12     GRU      14      0.161
# 1665  AQB12     GRU      15      0.171
# 1666  AQB12     GRU      16      0.187
# 1667  AQB12     GRU      17      0.172
# 1668  AQB12     GRU      18      0.197
# 1669  AQB12     GRU      19      0.179
# 1670  AQB12     GRU      20      0.194
# 1671  AQB12     GRU      21      0.167
# 1672  AQB12     GRU      22      0.172
# 1673  AQB12     GRU      23      0.184
# 1674  AQB12     GRU      24      0.186
# 1675  AQB12     GRU      25      0.176
# 1676  AQB12     GRU      26      0.185
# 1677  AQB12     GRU      27      0.182
# 1678  AQB12     GRU      28      0.178
# 1679  AQB12     GRU      29      0.196
# 1680  AQB12     RNN       0      0.201
# 1681  AQB12     RNN       1      0.218
# 1682  AQB12     RNN       2      0.254
# 1683  AQB12     RNN       3      0.242
# 1684  AQB12     RNN       4      0.226
# 1685  AQB12     RNN       5      0.212
# 1686  AQB12     RNN       6      0.230
# 1687  AQB12     RNN       7      0.213
# 1688  AQB12     RNN       8      0.235
# 1689  AQB12     RNN       9      0.221
# 1690  AQB12     RNN      10      0.241
# 1691  AQB12     RNN      11      0.229
# 1692  AQB12     RNN      12      0.202
# 1693  AQB12     RNN      13      0.216
# 1694  AQB12     RNN      14      0.191
# 1695  AQB12     RNN      15      0.197
# 1696  AQB12     RNN      16      0.220
# 1697  AQB12     RNN      17      0.208
# 1698  AQB12     RNN      18      0.261
# 1777  AQB12  SLSTM2       7      0.171
# 1778  AQB12  SLSTM2       8      0.169
# 1779  AQB12  SLSTM2       9      0.161
# 1780  AQB12  SLSTM2      10      0.134
# 1781  AQB12  SLSTM2      11      0.120
# 1782  AQB12  SLSTM2      12      0.142
# 1783  AQB12  SLSTM2      13      0.169
# 1784  AQB12  SLSTM2      14      0.147
# 1785  AQB12  SLSTM2      15      0.172
# 1786  AQB12  SLSTM2      16      0.147
# 1787  AQB12  SLSTM2      17      0.212
# 1788  AQB12  SLSTM2      18      0.127
# 1789  AQB12  SLSTM2      19      0.164
# 1790  AQB12  SLSTM2      20      0.134
# 1791  AQB12  SLSTM2      21      0.170
# 1792  AQB12  SLSTM2      22      0.140
# 1793  AQB12  SLSTM2      23      0.140
# 1794  AQB12  SLSTM2      24      0.134
# 1795  AQB12  SLSTM2      25      0.152
# 1796  AQB12  SLSTM2      26      0.408
# 1797  AQB12  SLSTM2      27      0.129
# 1798  AQB12  SLSTM2      28      0.163
# 1799  AQB12  SLSTM2      29      0.312

# %%
datasets = df['ds'].unique()
datasets
# Out:
# array(['AEC', 'KSH', 'AQI', 'AQB1', 'AQB6', 'AQB12'], dtype=object)

# %%
methods = df['model'].unique()
# methods = ['KFTS', 'PFTS', 'RF', 'GRU', 'RNN', 'LSTM', 'SLSTM', 'SLSTM2', 'SVR']
methods = ['KFTS', 'PFTS', 'RF', 'GRU', 'RNN', 'LSTM', 'SLSTM', 'SVR']
list(methods)
# Out:
# ['KFTS', 'PFTS', 'RF', 'GRU', 'RNN', 'LSTM', 'SLSTM', 'SVR']

# %% [markdown]
# ## Experiment Histograms

# %%
datasets2 = list(datasets)#['AEC', 'KSH', 'AQI', 'AQB1', 'AQB6', 'AQB12']

#datasets2 = ['AQI', 'AQB1', 'AQB6', 'AQB12']

methods2 = list(methods) #['KFTS', 'PFTS', 'VAR', 'SLSTM', 'LSTM', 'GRU', 'RNN', 'RF', 'SVR']

num_rows = len(datasets2)
num_cols = len(methods2)

fig, ax = plt.subplots(num_rows, num_cols, figsize=(15, 15))

for count1, dataset in enumerate(datasets2):

  for count2, method in enumerate(methods2):
    tmp = df[(df['ds'] == dataset) & (df['model'] == method)]['avg_nrmse']

    ax[count1][count2].hist(tmp)

    ax[count1][count2].set_ylim([0, 33])

    if count2 == 0:
      ax[count1][count2].set_ylabel(dataset)
    
    if count1 == 0:
      ax[count1][count2].set_title(method)

plt.tight_layout()

# %% [markdown]
# ## Hypothesis Test
#
# - Anova Test - Kruskal Wallis
# - Post Hoc: Wilcoxon
#
# $\alpha = .01$

# %%
from scipy import stats
import itertools

anova_result = {
    "dataset": [],
    "statistic": [],
    "pvalue": [],
    "result": []
}

posthoc_result = {
    "dataset": [],
    "methods": [],
    "statistic": [],
    "pvalue": [],
    "result": []
}

competing_methods = list(methods)#['KFTS', 'PFTS', 'VAR', 'SLSTM', 'LSTM', 'GRU', 'RNN', 'RF', 'SVR']
print(list(methods))

alpha = 0.01

anova_test = stats.kruskal #stats.friedmanchisquare #stats.kruskal 
post_hoc_test = stats.wilcoxon

for dataset in datasets:
  #if dataset != 'SONDA':
    samples = []
    for method in competing_methods:
      sample = df[(df['ds'] == dataset) & (df['model'] == method)]['avg_nrmse']
      #print(sample)
      samples.append(sample)

    result = anova_test(*samples)

    if result.pvalue > alpha:
      test = 'Fail to Reject H0'
    else:
      test = 'H0 rejected'

    print('ANOVA {} result: {}, {}'.format(dataset, result, test))
    
    anova_result["dataset"].append(dataset)
    anova_result["statistic"].append(result.statistic)
    anova_result["pvalue"].append(result.pvalue)
    anova_result["result"].append(test)

    if result.pvalue < alpha:
      for a,b in itertools.product(competing_methods , competing_methods):
        if a != b:
          i = competing_methods.index(a)
          j = competing_methods.index(b)
          result2 = post_hoc_test(samples[i],samples[j],alternative='greater') 

          if result2.pvalue > alpha:
            test = 'Fail to Reject H0'
          else:
            test = 'H0 rejected'

          print('\t Wilcoxon {} x {} = {}, {}'.format(a,b,result2, test))
          
          posthoc_result["dataset"].append(dataset)
          posthoc_result["methods"].append(a + " x " + b)
          posthoc_result["statistic"].append(result2.statistic)
          posthoc_result["pvalue"].append(result2.pvalue)
          posthoc_result["result"].append(test)

    print("")
# Out:
# ['KFTS', 'PFTS', 'RF', 'GRU', 'RNN', 'LSTM', 'SLSTM', 'SVR']
# ANOVA AEC result: KruskalResult(statistic=204.83402866459977, pvalue=1.0860153859818442e-40), H0 rejected
# 	 Wilcoxon KFTS x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991447360034), Fail to Reject H0
# 	 Wilcoxon KFTS x RF = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon KFTS x GRU = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991360698426), Fail to Reject H0
# 	 Wilcoxon KFTS x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon PFTS x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.552639966200389e-07), H0 rejected
# 	 Wilcoxon PFTS x RF = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon PFTS x GRU = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon PFTS x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon PFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon PFTS x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991349814353), Fail to Reject H0
# 	 Wilcoxon PFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon RF x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon RF x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected
# 	 Wilcoxon RF x GRU = WilcoxonResult(statistic=107.5, pvalue=0.9949313497866659), Fail to Reject H0
# 	 Wilcoxon RF x RNN = WilcoxonResult(statistic=101.5, pvalue=0.9964762878488634), Fail to Reject H0
# 	 Wilcoxon RF x LSTM = WilcoxonResult(statistic=65.5, pvalue=0.999703826202466), Fail to Reject H0
# 	 Wilcoxon RF x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon RF x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon GRU x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon GRU x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected
# 	 Wilcoxon GRU x RF = WilcoxonResult(statistic=357.5, pvalue=0.005068650213334185), H0 rejected
# 	 Wilcoxon GRU x RNN = WilcoxonResult(statistic=130.5, pvalue=0.9507818353966401), Fail to Reject H0
# 	 Wilcoxon GRU x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.999999137157106), Fail to Reject H0
# 	 Wilcoxon GRU x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon GRU x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon RNN x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon RNN x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon RNN x RF = WilcoxonResult(statistic=363.5, pvalue=0.0035237121511365547), H0 rejected
# 	 Wilcoxon RNN x GRU = WilcoxonResult(statistic=275.5, pvalue=0.04921816460335989), Fail to Reject H0
# 	 Wilcoxon RNN x LSTM = WilcoxonResult(statistic=1.0, pvalue=0.9999990478993845), Fail to Reject H0
# 	 Wilcoxon RNN x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon RNN x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon LSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.639301574362052e-07), H0 rejected
# 	 Wilcoxon LSTM x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon LSTM x RF = WilcoxonResult(statistic=399.5, pvalue=0.0002961737975340144), H0 rejected
# 	 Wilcoxon LSTM x GRU = WilcoxonResult(statistic=465.0, pvalue=8.628428940029018e-07), H0 rejected
# 	 Wilcoxon LSTM x RNN = WilcoxonResult(statistic=464.0, pvalue=9.521006154492751e-07), H0 rejected
# 	 Wilcoxon LSTM x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon LSTM x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon SLSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon SLSTM x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.650185646450623e-07), H0 rejected
# 	 Wilcoxon SLSTM x RF = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SLSTM x GRU = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SLSTM x RNN = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon SLSTM x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SLSTM x SVR = WilcoxonResult(statistic=1.0, pvalue=0.9999990395394476), Fail to Reject H0
# 	 Wilcoxon SVR x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x RF = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x GRU = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon SVR x RNN = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon SVR x SLSTM = WilcoxonResult(statistic=464.0, pvalue=9.604605524515698e-07), H0 rejected
#
# ANOVA KSH result: KruskalResult(statistic=151.69201829583142, pvalue=1.791068948524908e-29), H0 rejected
# 	 Wilcoxon KFTS x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991360698426), Fail to Reject H0
# 	 Wilcoxon KFTS x RF = WilcoxonResult(statistic=191.0, pvalue=0.803382865126566), Fail to Reject H0
# 	 Wilcoxon KFTS x GRU = WilcoxonResult(statistic=26.5, pvalue=0.9999713096054786), Fail to Reject H0
# 	 Wilcoxon KFTS x RNN = WilcoxonResult(statistic=435.0, pvalue=1.5241188290890158e-05), H0 rejected
# 	 Wilcoxon KFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991366136172), Fail to Reject H0
# 	 Wilcoxon KFTS x SLSTM = WilcoxonResult(statistic=31.0, pvalue=0.9999724609914642), Fail to Reject H0
# 	 Wilcoxon KFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon PFTS x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.639301574362052e-07), H0 rejected
# 	 Wilcoxon PFTS x RF = WilcoxonResult(statistic=435.0, pvalue=1.5524051643286797e-05), H0 rejected
# 	 Wilcoxon PFTS x GRU = WilcoxonResult(statistic=433.0, pvalue=1.8550865717047305e-05), H0 rejected
# 	 Wilcoxon PFTS x RNN = WilcoxonResult(statistic=465.0, pvalue=8.644742180097877e-07), H0 rejected
# 	 Wilcoxon PFTS x LSTM = WilcoxonResult(statistic=458.0, pvalue=1.749293590648135e-06), H0 rejected
# 	 Wilcoxon PFTS x SLSTM = WilcoxonResult(statistic=368.5, pvalue=0.0025748602792314175), H0 rejected
# 	 Wilcoxon PFTS x SVR = WilcoxonResult(statistic=103.0, pvalue=0.9961361460933673), Fail to Reject H0
# 	 Wilcoxon RF x KFTS = WilcoxonResult(statistic=274.0, pvalue=0.19661713487343396), Fail to Reject H0
# 	 Wilcoxon RF x PFTS = WilcoxonResult(statistic=30.0, pvalue=0.9999844759483567), Fail to Reject H0
# 	 Wilcoxon RF x GRU = WilcoxonResult(statistic=180.5, pvalue=0.8577555327765192), Fail to Reject H0
# 	 Wilcoxon RF x RNN = WilcoxonResult(statistic=387.5, pvalue=0.0007148214703608735), H0 rejected
# 	 Wilcoxon RF x LSTM = WilcoxonResult(statistic=79.0, pvalue=0.9976287480822389), Fail to Reject H0
# 	 Wilcoxon RF x SLSTM = WilcoxonResult(statistic=24.5, pvalue=0.9999850197079415), Fail to Reject H0
# 	 Wilcoxon RF x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon GRU x KFTS = WilcoxonResult(statistic=379.5, pvalue=2.869039452138459e-05), H0 rejected
# 	 Wilcoxon GRU x PFTS = WilcoxonResult(statistic=32.0, pvalue=0.999981449134283), Fail to Reject H0
# 	 Wilcoxon GRU x RF = WilcoxonResult(statistic=284.5, pvalue=0.14224446722348077), Fail to Reject H0
# 	 Wilcoxon GRU x RNN = WilcoxonResult(statistic=465.0, pvalue=8.568833480366938e-07), H0 rejected
# 	 Wilcoxon GRU x LSTM = WilcoxonResult(statistic=57.0, pvalue=0.9998471444112015), Fail to Reject H0
# 	 Wilcoxon GRU x SLSTM = WilcoxonResult(statistic=94.0, pvalue=0.9978119394074377), Fail to Reject H0
# 	 Wilcoxon GRU x SVR = WilcoxonResult(statistic=18.0, pvalue=0.9999948795964244), Fail to Reject H0
# 	 Wilcoxon RNN x KFTS = WilcoxonResult(statistic=30.0, pvalue=0.9999847588117091), Fail to Reject H0
# 	 Wilcoxon RNN x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.999999135525782), Fail to Reject H0
# 	 Wilcoxon RNN x RF = WilcoxonResult(statistic=77.5, pvalue=0.9992851785296392), Fail to Reject H0
# 	 Wilcoxon RNN x GRU = WilcoxonResult(statistic=0.0, pvalue=0.999999143116652), Fail to Reject H0
# 	 Wilcoxon RNN x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991366136172), Fail to Reject H0
# 	 Wilcoxon RNN x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999987201833946), Fail to Reject H0
# 	 Wilcoxon RNN x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon LSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.63386382806499e-07), H0 rejected
# 	 Wilcoxon LSTM x PFTS = WilcoxonResult(statistic=7.0, pvalue=0.9999982507064094), Fail to Reject H0
# 	 Wilcoxon LSTM x RF = WilcoxonResult(statistic=327.0, pvalue=0.0023712519177610833), H0 rejected
# 	 Wilcoxon LSTM x GRU = WilcoxonResult(statistic=408.0, pvalue=0.00015285558879855914), H0 rejected
# 	 Wilcoxon LSTM x RNN = WilcoxonResult(statistic=465.0, pvalue=8.63386382806499e-07), H0 rejected
# 	 Wilcoxon LSTM x SLSTM = WilcoxonResult(statistic=145.0, pvalue=0.9640558525249688), Fail to Reject H0
# 	 Wilcoxon LSTM x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991349814353), Fail to Reject H0
# 	 Wilcoxon SLSTM x KFTS = WilcoxonResult(statistic=404.0, pvalue=2.7539008535773036e-05), H0 rejected
# 	 Wilcoxon SLSTM x PFTS = WilcoxonResult(statistic=96.5, pvalue=0.9974251397207686), Fail to Reject H0
# 	 Wilcoxon SLSTM x RF = WilcoxonResult(statistic=410.5, pvalue=1.4980292058521604e-05), H0 rejected
# 	 Wilcoxon SLSTM x GRU = WilcoxonResult(statistic=371.0, pvalue=0.002188060592562319), H0 rejected
# 	 Wilcoxon SLSTM x RNN = WilcoxonResult(statistic=435.0, pvalue=1.2798166053566659e-06), H0 rejected
# 	 Wilcoxon SLSTM x LSTM = WilcoxonResult(statistic=320.0, pvalue=0.035944147475031205), Fail to Reject H0
# 	 Wilcoxon SLSTM x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon SVR x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon SVR x PFTS = WilcoxonResult(statistic=362.0, pvalue=0.0038638539066327368), H0 rejected
# 	 Wilcoxon SVR x RF = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x GRU = WilcoxonResult(statistic=447.0, pvalue=5.120403575588226e-06), H0 rejected
# 	 Wilcoxon SVR x RNN = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon SVR x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.650185646450623e-07), H0 rejected
# 	 Wilcoxon SVR x SLSTM = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
#
# ANOVA AQI result: KruskalResult(statistic=7.411324299675933, pvalue=0.38734406805870275), Fail to Reject H0
#
# ANOVA AQB1 result: KruskalResult(statistic=113.24128187087774, pvalue=1.9502203339100973e-21), H0 rejected
# 	 Wilcoxon KFTS x PFTS = WilcoxonResult(statistic=8.5, pvalue=0.9999979663876821), Fail to Reject H0
# 	 Wilcoxon KFTS x RF = WilcoxonResult(statistic=70.0, pvalue=0.9995884699202195), Fail to Reject H0
# 	 Wilcoxon KFTS x GRU = WilcoxonResult(statistic=394.0, pvalue=0.000443145365687359), H0 rejected
# 	 Wilcoxon KFTS x RNN = WilcoxonResult(statistic=354.5, pvalue=0.0015195031752373623), H0 rejected
# 	 Wilcoxon KFTS x LSTM = WilcoxonResult(statistic=320.0, pvalue=0.01327523372905371), Fail to Reject H0
# 	 Wilcoxon KFTS x SLSTM = WilcoxonResult(statistic=53.5, pvalue=0.999435448455168), Fail to Reject H0
# 	 Wilcoxon KFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon PFTS x KFTS = WilcoxonResult(statistic=456.5, pvalue=2.0336123178767985e-06), H0 rejected
# 	 Wilcoxon PFTS x RF = WilcoxonResult(statistic=299.5, pvalue=0.08407824068683578), Fail to Reject H0
# 	 Wilcoxon PFTS x GRU = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon PFTS x RNN = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon PFTS x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.639301574362052e-07), H0 rejected
# 	 Wilcoxon PFTS x SLSTM = WilcoxonResult(statistic=285.5, pvalue=0.07070066747353469), Fail to Reject H0
# 	 Wilcoxon PFTS x SVR = WilcoxonResult(statistic=13.0, pvalue=0.9999968322171237), Fail to Reject H0
# 	 Wilcoxon RF x KFTS = WilcoxonResult(statistic=395.0, pvalue=0.00041153007978041693), H0 rejected
# 	 Wilcoxon RF x PFTS = WilcoxonResult(statistic=165.5, pvalue=0.9159217593131642), Fail to Reject H0
# 	 Wilcoxon RF x GRU = WilcoxonResult(statistic=435.0, pvalue=1.2737941990435096e-06), H0 rejected
# 	 Wilcoxon RF x RNN = WilcoxonResult(statistic=461.0, pvalue=1.2929755306007707e-06), H0 rejected
# 	 Wilcoxon RF x LSTM = WilcoxonResult(statistic=401.0, pvalue=3.238269271500459e-06), H0 rejected
# 	 Wilcoxon RF x SLSTM = WilcoxonResult(statistic=194.0, pvalue=0.31913178308158235), Fail to Reject H0
# 	 Wilcoxon RF x SVR = WilcoxonResult(statistic=83.0, pvalue=0.9989479436372486), Fail to Reject H0
# 	 Wilcoxon GRU x KFTS = WilcoxonResult(statistic=71.0, pvalue=0.9995568546343127), Fail to Reject H0
# 	 Wilcoxon GRU x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon GRU x RF = WilcoxonResult(statistic=0.0, pvalue=0.999998726205801), Fail to Reject H0
# 	 Wilcoxon GRU x RNN = WilcoxonResult(statistic=6.0, pvalue=0.9999400305235134), Fail to Reject H0
# 	 Wilcoxon GRU x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999993328596262), Fail to Reject H0
# 	 Wilcoxon GRU x SLSTM = WilcoxonResult(statistic=17.5, pvalue=0.9999951411801047), Fail to Reject H0
# 	 Wilcoxon GRU x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon RNN x KFTS = WilcoxonResult(statistic=80.5, pvalue=0.9984804968247626), Fail to Reject H0
# 	 Wilcoxon RNN x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon RNN x RF = WilcoxonResult(statistic=4.0, pvalue=0.9999987070244694), Fail to Reject H0
# 	 Wilcoxon RNN x GRU = WilcoxonResult(statistic=225.0, pvalue=5.9969476486611175e-05), H0 rejected
# 	 Wilcoxon RNN x LSTM = WilcoxonResult(statistic=67.5, pvalue=0.999073342581081), Fail to Reject H0
# 	 Wilcoxon RNN x SLSTM = WilcoxonResult(statistic=20.0, pvalue=0.9999938325052186), Fail to Reject H0
# 	 Wilcoxon RNN x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon LSTM x KFTS = WilcoxonResult(statistic=115.0, pvalue=0.9867247662709463), Fail to Reject H0
# 	 Wilcoxon LSTM x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991360698426), Fail to Reject H0
# 	 Wilcoxon LSTM x RF = WilcoxonResult(statistic=5.0, pvalue=0.9999967617307285), Fail to Reject H0
# 	 Wilcoxon LSTM x GRU = WilcoxonResult(statistic=465.0, pvalue=6.671403738826888e-07), H0 rejected
# 	 Wilcoxon LSTM x RNN = WilcoxonResult(statistic=338.5, pvalue=0.0009266574189189217), H0 rejected
# 	 Wilcoxon LSTM x SLSTM = WilcoxonResult(statistic=18.0, pvalue=0.9999802344167897), Fail to Reject H0
# 	 Wilcoxon LSTM x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon SLSTM x KFTS = WilcoxonResult(statistic=324.5, pvalue=0.0005645515448320608), H0 rejected
# 	 Wilcoxon SLSTM x PFTS = WilcoxonResult(statistic=149.5, pvalue=0.9292993325264653), Fail to Reject H0
# 	 Wilcoxon SLSTM x RF = WilcoxonResult(statistic=157.0, pvalue=0.6808682169184177), Fail to Reject H0
# 	 Wilcoxon SLSTM x GRU = WilcoxonResult(statistic=447.5, pvalue=4.858819895303869e-06), H0 rejected
# 	 Wilcoxon SLSTM x RNN = WilcoxonResult(statistic=445.0, pvalue=6.167494781417338e-06), H0 rejected
# 	 Wilcoxon SLSTM x LSTM = WilcoxonResult(statistic=360.0, pvalue=1.9765583210266594e-05), H0 rejected
# 	 Wilcoxon SLSTM x SVR = WilcoxonResult(statistic=28.0, pvalue=0.9999870292044404), Fail to Reject H0
# 	 Wilcoxon SVR x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x PFTS = WilcoxonResult(statistic=452.0, pvalue=3.1677828763968257e-06), H0 rejected
# 	 Wilcoxon SVR x RF = WilcoxonResult(statistic=382.0, pvalue=0.0010520563627513598), H0 rejected
# 	 Wilcoxon SVR x GRU = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x RNN = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x SLSTM = WilcoxonResult(statistic=437.0, pvalue=1.2970795559650175e-05), H0 rejected
#
# ANOVA AQB6 result: KruskalResult(statistic=126.86064773551323, pvalue=2.843852421393926e-24), H0 rejected
# 	 Wilcoxon KFTS x PFTS = WilcoxonResult(statistic=14.0, pvalue=0.9999965178459045), Fail to Reject H0
# 	 Wilcoxon KFTS x RF = WilcoxonResult(statistic=1.5, pvalue=0.999998514371449), Fail to Reject H0
# 	 Wilcoxon KFTS x GRU = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon KFTS x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon KFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon KFTS x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991328011858), Fail to Reject H0
# 	 Wilcoxon PFTS x KFTS = WilcoxonResult(statistic=451.0, pvalue=3.482154095552842e-06), H0 rejected
# 	 Wilcoxon PFTS x RF = WilcoxonResult(statistic=283.5, pvalue=0.07675300042881461), Fail to Reject H0
# 	 Wilcoxon PFTS x GRU = WilcoxonResult(statistic=29.0, pvalue=0.9999858313102586), Fail to Reject H0
# 	 Wilcoxon PFTS x RNN = WilcoxonResult(statistic=29.0, pvalue=0.9999858313102586), Fail to Reject H0
# 	 Wilcoxon PFTS x LSTM = WilcoxonResult(statistic=2.0, pvalue=0.9999989393112374), Fail to Reject H0
# 	 Wilcoxon PFTS x SLSTM = WilcoxonResult(statistic=138.0, pvalue=0.9572197308505287), Fail to Reject H0
# 	 Wilcoxon PFTS x SVR = WilcoxonResult(statistic=1.0, pvalue=0.9999990395394476), Fail to Reject H0
# 	 Wilcoxon RF x KFTS = WilcoxonResult(statistic=433.5, pvalue=1.485628550969863e-06), H0 rejected
# 	 Wilcoxon RF x PFTS = WilcoxonResult(statistic=151.5, pvalue=0.9232469995711854), Fail to Reject H0
# 	 Wilcoxon RF x GRU = WilcoxonResult(statistic=95.0, pvalue=0.9959634472181357), Fail to Reject H0
# 	 Wilcoxon RF x RNN = WilcoxonResult(statistic=105.0, pvalue=0.995636942330913), Fail to Reject H0
# 	 Wilcoxon RF x LSTM = WilcoxonResult(statistic=92.0, pvalue=0.9980747549172693), Fail to Reject H0
# 	 Wilcoxon RF x SLSTM = WilcoxonResult(statistic=112.0, pvalue=0.9934077618279382), Fail to Reject H0
# 	 Wilcoxon RF x SVR = WilcoxonResult(statistic=72.0, pvalue=0.9995189699839074), Fail to Reject H0
# 	 Wilcoxon GRU x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon GRU x PFTS = WilcoxonResult(statistic=436.0, pvalue=1.4168689741375753e-05), H0 rejected
# 	 Wilcoxon GRU x RF = WilcoxonResult(statistic=340.0, pvalue=0.004036552781864376), H0 rejected
# 	 Wilcoxon GRU x RNN = WilcoxonResult(statistic=230.5, pvalue=0.1590585092512331), Fail to Reject H0
# 	 Wilcoxon GRU x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991468911622), Fail to Reject H0
# 	 Wilcoxon GRU x SLSTM = WilcoxonResult(statistic=257.0, pvalue=0.19650640706342615), Fail to Reject H0
# 	 Wilcoxon GRU x SVR = WilcoxonResult(statistic=21.5, pvalue=0.9999928844149337), Fail to Reject H0
# 	 Wilcoxon RNN x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected
# 	 Wilcoxon RNN x PFTS = WilcoxonResult(statistic=436.0, pvalue=1.4168689741375753e-05), H0 rejected
# 	 Wilcoxon RNN x RF = WilcoxonResult(statistic=360.0, pvalue=0.0043630576690869725), H0 rejected
# 	 Wilcoxon RNN x GRU = WilcoxonResult(statistic=147.5, pvalue=0.8409414907487669), Fail to Reject H0
# 	 Wilcoxon RNN x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999987441321034), Fail to Reject H0
# 	 Wilcoxon RNN x SLSTM = WilcoxonResult(statistic=261.5, pvalue=0.17066716998749148), Fail to Reject H0
# 	 Wilcoxon RNN x SVR = WilcoxonResult(statistic=14.5, pvalue=0.9999963394867952), Fail to Reject H0
# 	 Wilcoxon LSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected
# 	 Wilcoxon LSTM x PFTS = WilcoxonResult(statistic=463.0, pvalue=1.0606887626214274e-06), H0 rejected
# 	 Wilcoxon LSTM x RF = WilcoxonResult(statistic=373.0, pvalue=0.0019252450827307542), H0 rejected
# 	 Wilcoxon LSTM x GRU = WilcoxonResult(statistic=465.0, pvalue=8.531088377398274e-07), H0 rejected
# 	 Wilcoxon LSTM x RNN = WilcoxonResult(statistic=435.0, pvalue=1.255867896558667e-06), H0 rejected
# 	 Wilcoxon LSTM x SLSTM = WilcoxonResult(statistic=306.0, pvalue=0.06528564485895866), Fail to Reject H0
# 	 Wilcoxon LSTM x SVR = WilcoxonResult(statistic=49.0, pvalue=0.9998656383573616), Fail to Reject H0
# 	 Wilcoxon SLSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon SLSTM x PFTS = WilcoxonResult(statistic=297.0, pvalue=0.04278026914947127), Fail to Reject H0
# 	 Wilcoxon SLSTM x RF = WilcoxonResult(statistic=353.0, pvalue=0.006592238172061759), H0 rejected
# 	 Wilcoxon SLSTM x GRU = WilcoxonResult(statistic=178.0, pvalue=0.8034935929365739), Fail to Reject H0
# 	 Wilcoxon SLSTM x RNN = WilcoxonResult(statistic=173.5, pvalue=0.8293328300125085), Fail to Reject H0
# 	 Wilcoxon SLSTM x LSTM = WilcoxonResult(statistic=159.0, pvalue=0.9347143551410413), Fail to Reject H0
# 	 Wilcoxon SLSTM x SVR = WilcoxonResult(statistic=1.0, pvalue=0.9999985755483439), Fail to Reject H0
# 	 Wilcoxon SVR x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.671988141602892e-07), H0 rejected
# 	 Wilcoxon SVR x PFTS = WilcoxonResult(statistic=464.0, pvalue=9.604605524515698e-07), H0 rejected
# 	 Wilcoxon SVR x RF = WilcoxonResult(statistic=393.0, pvalue=0.0004810300160926053), H0 rejected
# 	 Wilcoxon SVR x GRU = WilcoxonResult(statistic=443.5, pvalue=7.1155850662376935e-06), H0 rejected
# 	 Wilcoxon SVR x RNN = WilcoxonResult(statistic=450.5, pvalue=3.660513204803045e-06), H0 rejected
# 	 Wilcoxon SVR x LSTM = WilcoxonResult(statistic=386.0, pvalue=0.00013436164263835193), H0 rejected
# 	 Wilcoxon SVR x SLSTM = WilcoxonResult(statistic=434.0, pvalue=1.4244516560381606e-06), H0 rejected
#
# ANOVA AQB12 result: KruskalResult(statistic=158.05240625779106, pvalue=8.241154116274595e-31), H0 rejected
# 	 Wilcoxon KFTS x PFTS = WilcoxonResult(statistic=0.0, pvalue=0.9999991414947408), Fail to Reject H0
# 	 Wilcoxon KFTS x RF = WilcoxonResult(statistic=65.5, pvalue=0.9997051148956468), Fail to Reject H0
# 	 Wilcoxon KFTS x GRU = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon KFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon KFTS x SLSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991360698426), Fail to Reject H0
# 	 Wilcoxon KFTS x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991333466779), Fail to Reject H0
# 	 Wilcoxon PFTS x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.585052591922721e-07), H0 rejected
# 	 Wilcoxon PFTS x RF = WilcoxonResult(statistic=262.0, pvalue=0.2718752134170579), Fail to Reject H0
# 	 Wilcoxon PFTS x GRU = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon PFTS x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991338918834), Fail to Reject H0
# 	 Wilcoxon PFTS x LSTM = WilcoxonResult(statistic=0.0, pvalue=0.9999991360698426), Fail to Reject H0
# 	 Wilcoxon PFTS x SLSTM = WilcoxonResult(statistic=34.5, pvalue=0.999976790498747), Fail to Reject H0
# 	 Wilcoxon PFTS x SVR = WilcoxonResult(statistic=3.0, pvalue=0.9999988232895024), Fail to Reject H0
# 	 Wilcoxon RF x KFTS = WilcoxonResult(statistic=399.5, pvalue=0.0002948851043531572), H0 rejected
# 	 Wilcoxon RF x PFTS = WilcoxonResult(statistic=203.0, pvalue=0.7281247865829421), Fail to Reject H0
# 	 Wilcoxon RF x GRU = WilcoxonResult(statistic=88.0, pvalue=0.9985220258416986), Fail to Reject H0
# 	 Wilcoxon RF x RNN = WilcoxonResult(statistic=75.0, pvalue=0.9994013309000008), Fail to Reject H0
# 	 Wilcoxon RF x LSTM = WilcoxonResult(statistic=87.0, pvalue=0.9986180796970149), Fail to Reject H0
# 	 Wilcoxon RF x SLSTM = WilcoxonResult(statistic=87.0, pvalue=0.9986187962667273), Fail to Reject H0
# 	 Wilcoxon RF x SVR = WilcoxonResult(statistic=25.0, pvalue=0.999990135257742), Fail to Reject H0
# 	 Wilcoxon GRU x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon GRU x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected
# 	 Wilcoxon GRU x RF = WilcoxonResult(statistic=377.0, pvalue=0.0014779741583013802), H0 rejected
# 	 Wilcoxon GRU x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991414947408), Fail to Reject H0
# 	 Wilcoxon GRU x LSTM = WilcoxonResult(statistic=73.5, pvalue=0.9990910779569657), Fail to Reject H0
# 	 Wilcoxon GRU x SLSTM = WilcoxonResult(statistic=367.0, pvalue=0.0028304089206328594), H0 rejected
# 	 Wilcoxon GRU x SVR = WilcoxonResult(statistic=229.5, pvalue=0.5246050269771219), Fail to Reject H0
# 	 Wilcoxon RNN x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon RNN x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.66108116572057e-07), H0 rejected
# 	 Wilcoxon RNN x RF = WilcoxonResult(statistic=390.0, pvalue=0.0005986690999992266), H0 rejected
# 	 Wilcoxon RNN x GRU = WilcoxonResult(statistic=465.0, pvalue=8.585052591922721e-07), H0 rejected
# 	 Wilcoxon RNN x LSTM = WilcoxonResult(statistic=465.0, pvalue=8.612141413715367e-07), H0 rejected
# 	 Wilcoxon RNN x SLSTM = WilcoxonResult(statistic=401.0, pvalue=0.0002641822645552567), H0 rejected
# 	 Wilcoxon RNN x SVR = WilcoxonResult(statistic=330.0, pvalue=0.02245095618673873), Fail to Reject H0
# 	 Wilcoxon LSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon LSTM x PFTS = WilcoxonResult(statistic=465.0, pvalue=8.639301574362052e-07), H0 rejected
# 	 Wilcoxon LSTM x RF = WilcoxonResult(statistic=378.0, pvalue=0.0013819203029850952), H0 rejected
# 	 Wilcoxon LSTM x GRU = WilcoxonResult(statistic=361.5, pvalue=0.0009089220430342493), H0 rejected
# 	 Wilcoxon LSTM x RNN = WilcoxonResult(statistic=0.0, pvalue=0.9999991387858587), Fail to Reject H0
# 	 Wilcoxon LSTM x SLSTM = WilcoxonResult(statistic=373.0, pvalue=0.0019224374798523529), H0 rejected
# 	 Wilcoxon LSTM x SVR = WilcoxonResult(statistic=246.5, pvalue=0.38668117895978876), Fail to Reject H0
# 	 Wilcoxon SLSTM x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.639301574362052e-07), H0 rejected
# 	 Wilcoxon SLSTM x PFTS = WilcoxonResult(statistic=430.5, pvalue=2.3209501253010274e-05), H0 rejected
# 	 Wilcoxon SLSTM x RF = WilcoxonResult(statistic=378.0, pvalue=0.001381203733272644), H0 rejected
# 	 Wilcoxon SLSTM x GRU = WilcoxonResult(statistic=98.0, pvalue=0.9971695910793671), Fail to Reject H0
# 	 Wilcoxon SLSTM x RNN = WilcoxonResult(statistic=64.0, pvalue=0.9997358177354447), Fail to Reject H0
# 	 Wilcoxon SLSTM x LSTM = WilcoxonResult(statistic=92.0, pvalue=0.9980775625201477), Fail to Reject H0
# 	 Wilcoxon SLSTM x SVR = WilcoxonResult(statistic=0.0, pvalue=0.9999991344368026), Fail to Reject H0
# 	 Wilcoxon SVR x KFTS = WilcoxonResult(statistic=465.0, pvalue=8.666533220995528e-07), H0 rejected
# 	 Wilcoxon SVR x PFTS = WilcoxonResult(statistic=462.0, pvalue=1.1767104975607673e-06), H0 rejected
# 	 Wilcoxon SVR x RF = WilcoxonResult(statistic=440.0, pvalue=9.864742257901843e-06), H0 rejected
# 	 Wilcoxon SVR x GRU = WilcoxonResult(statistic=235.5, pvalue=0.4753949730228781), Fail to Reject H0
# 	 Wilcoxon SVR x RNN = WilcoxonResult(statistic=135.0, pvalue=0.9775490438132612), Fail to Reject H0
# 	 Wilcoxon SVR x LSTM = WilcoxonResult(statistic=218.5, pvalue=0.6133188210402113), Fail to Reject H0
# 	 Wilcoxon SVR x SLSTM = WilcoxonResult(statistic=465.0, pvalue=8.655631974598644e-07), H0 rejected

# %%
df_anova_result = pd.DataFrame(anova_result)
df_anova_result
# Out:
#   dataset   statistic        pvalue             result
# 0     AEC  204.834029  1.086015e-40        H0 rejected
# 1     KSH  151.692018  1.791069e-29        H0 rejected
# 2     AQI    7.411324  3.873441e-01  Fail to Reject H0
# 3    AQB1  113.241282  1.950220e-21        H0 rejected
# 4    AQB6  126.860648  2.843852e-24        H0 rejected
# 5   AQB12  158.052406  8.241154e-31        H0 rejected

# %%
print(len(posthoc_result['dataset']))
print(len(posthoc_result['methods']))
# Out:
# 280
# 280

# %%
df_posthoc_result = pd.DataFrame(posthoc_result, columns=list(posthoc_result.keys()))
df_posthoc_result
# Out:
#     dataset       methods  statistic        pvalue             result
# 0       AEC   KFTS x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 1       AEC     KFTS x RF        0.0  9.999991e-01  Fail to Reject H0
# 2       AEC    KFTS x GRU        0.0  9.999991e-01  Fail to Reject H0
# 3       AEC    KFTS x RNN        0.0  9.999991e-01  Fail to Reject H0
# 4       AEC   KFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 5       AEC  KFTS x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 6       AEC    KFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 7       AEC   PFTS x KFTS      465.0  8.552640e-07        H0 rejected
# 8       AEC     PFTS x RF        0.0  9.999991e-01  Fail to Reject H0
# 9       AEC    PFTS x GRU        0.0  9.999991e-01  Fail to Reject H0
# 10      AEC    PFTS x RNN        0.0  9.999991e-01  Fail to Reject H0
# 11      AEC   PFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 12      AEC  PFTS x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 13      AEC    PFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 14      AEC     RF x KFTS      465.0  8.671988e-07        H0 rejected
# 15      AEC     RF x PFTS      465.0  8.655632e-07        H0 rejected
# 16      AEC      RF x GRU      107.5  9.949313e-01  Fail to Reject H0
# 17      AEC      RF x RNN      101.5  9.964763e-01  Fail to Reject H0
# 18      AEC     RF x LSTM       65.5  9.997038e-01  Fail to Reject H0
# 19      AEC    RF x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 20      AEC      RF x SVR        0.0  9.999991e-01  Fail to Reject H0
# 21      AEC    GRU x KFTS      465.0  8.661081e-07        H0 rejected
# 22      AEC    GRU x PFTS      465.0  8.655632e-07        H0 rejected
# 23      AEC      GRU x RF      357.5  5.068650e-03        H0 rejected
# 24      AEC     GRU x RNN      130.5  9.507818e-01  Fail to Reject H0
# 25      AEC    GRU x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 26      AEC   GRU x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 27      AEC     GRU x SVR        0.0  9.999991e-01  Fail to Reject H0
# 28      AEC    RNN x KFTS      465.0  8.661081e-07        H0 rejected
# 29      AEC    RNN x PFTS      465.0  8.666533e-07        H0 rejected
# 30      AEC      RNN x RF      363.5  3.523712e-03        H0 rejected
# 31      AEC     RNN x GRU      275.5  4.921816e-02  Fail to Reject H0
# 32      AEC    RNN x LSTM        1.0  9.999990e-01  Fail to Reject H0
# 33      AEC   RNN x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 34      AEC     RNN x SVR        0.0  9.999991e-01  Fail to Reject H0
# 35      AEC   LSTM x KFTS      465.0  8.639302e-07        H0 rejected
# 36      AEC   LSTM x PFTS      465.0  8.661081e-07        H0 rejected
# 37      AEC     LSTM x RF      399.5  2.961738e-04        H0 rejected
# 38      AEC    LSTM x GRU      465.0  8.628429e-07        H0 rejected
# 39      AEC    LSTM x RNN      464.0  9.521006e-07        H0 rejected
# 40      AEC  LSTM x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 41      AEC    LSTM x SVR        0.0  9.999991e-01  Fail to Reject H0
# 42      AEC  SLSTM x KFTS      465.0  8.661081e-07        H0 rejected
# 43      AEC  SLSTM x PFTS      465.0  8.650186e-07        H0 rejected
# 44      AEC    SLSTM x RF      465.0  8.666533e-07        H0 rejected
# 45      AEC   SLSTM x GRU      465.0  8.666533e-07        H0 rejected
# 46      AEC   SLSTM x RNN      465.0  8.671988e-07        H0 rejected
# 47      AEC  SLSTM x LSTM      465.0  8.666533e-07        H0 rejected
# 48      AEC   SLSTM x SVR        1.0  9.999990e-01  Fail to Reject H0
# 49      AEC    SVR x KFTS      465.0  8.666533e-07        H0 rejected
# 50      AEC    SVR x PFTS      465.0  8.666533e-07        H0 rejected
# 51      AEC      SVR x RF      465.0  8.666533e-07        H0 rejected
# 52      AEC     SVR x GRU      465.0  8.671988e-07        H0 rejected
# 53      AEC     SVR x RNN      465.0  8.666533e-07        H0 rejected
# 54      AEC    SVR x LSTM      465.0  8.671988e-07        H0 rejected
# 55      AEC   SVR x SLSTM      464.0  9.604606e-07        H0 rejected
# 56      KSH   KFTS x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 57      KSH     KFTS x RF      191.0  8.033829e-01  Fail to Reject H0
# 58      KSH    KFTS x GRU       26.5  9.999713e-01  Fail to Reject H0
# 59      KSH    KFTS x RNN      435.0  1.524119e-05        H0 rejected
# 60      KSH   KFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 61      KSH  KFTS x SLSTM       31.0  9.999725e-01  Fail to Reject H0
# 62      KSH    KFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 63      KSH   PFTS x KFTS      465.0  8.639302e-07        H0 rejected
# 64      KSH     PFTS x RF      435.0  1.552405e-05        H0 rejected
# 65      KSH    PFTS x GRU      433.0  1.855087e-05        H0 rejected
# 66      KSH    PFTS x RNN      465.0  8.644742e-07        H0 rejected
# 67      KSH   PFTS x LSTM      458.0  1.749294e-06        H0 rejected
# 68      KSH  PFTS x SLSTM      368.5  2.574860e-03        H0 rejected
# 69      KSH    PFTS x SVR      103.0  9.961361e-01  Fail to Reject H0
# 70      KSH     RF x KFTS      274.0  1.966171e-01  Fail to Reject H0
# 71      KSH     RF x PFTS       30.0  9.999845e-01  Fail to Reject H0
# 72      KSH      RF x GRU      180.5  8.577555e-01  Fail to Reject H0
# 73      KSH      RF x RNN      387.5  7.148215e-04        H0 rejected
# 74      KSH     RF x LSTM       79.0  9.976287e-01  Fail to Reject H0
# 75      KSH    RF x SLSTM       24.5  9.999850e-01  Fail to Reject H0
# 76      KSH      RF x SVR        0.0  9.999991e-01  Fail to Reject H0
# 77      KSH    GRU x KFTS      379.5  2.869039e-05        H0 rejected
# 78      KSH    GRU x PFTS       32.0  9.999814e-01  Fail to Reject H0
# 79      KSH      GRU x RF      284.5  1.422445e-01  Fail to Reject H0
# 80      KSH     GRU x RNN      465.0  8.568833e-07        H0 rejected
# 81      KSH    GRU x LSTM       57.0  9.998471e-01  Fail to Reject H0
# 82      KSH   GRU x SLSTM       94.0  9.978119e-01  Fail to Reject H0
# 83      KSH     GRU x SVR       18.0  9.999949e-01  Fail to Reject H0
# 84      KSH    RNN x KFTS       30.0  9.999848e-01  Fail to Reject H0
# 85      KSH    RNN x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 86      KSH      RNN x RF       77.5  9.992852e-01  Fail to Reject H0
# 87      KSH     RNN x GRU        0.0  9.999991e-01  Fail to Reject H0
# 88      KSH    RNN x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 89      KSH   RNN x SLSTM        0.0  9.999987e-01  Fail to Reject H0
# 90      KSH     RNN x SVR        0.0  9.999991e-01  Fail to Reject H0
# 91      KSH   LSTM x KFTS      465.0  8.633864e-07        H0 rejected
# 92      KSH   LSTM x PFTS        7.0  9.999983e-01  Fail to Reject H0
# 93      KSH     LSTM x RF      327.0  2.371252e-03        H0 rejected
# 94      KSH    LSTM x GRU      408.0  1.528556e-04        H0 rejected
# 95      KSH    LSTM x RNN      465.0  8.633864e-07        H0 rejected
# 96      KSH  LSTM x SLSTM      145.0  9.640559e-01  Fail to Reject H0
# 97      KSH    LSTM x SVR        0.0  9.999991e-01  Fail to Reject H0
# 98      KSH  SLSTM x KFTS      404.0  2.753901e-05        H0 rejected
# 99      KSH  SLSTM x PFTS       96.5  9.974251e-01  Fail to Reject H0
# 100     KSH    SLSTM x RF      410.5  1.498029e-05        H0 rejected
# 101     KSH   SLSTM x GRU      371.0  2.188061e-03        H0 rejected
# 102     KSH   SLSTM x RNN      435.0  1.279817e-06        H0 rejected
# 103     KSH  SLSTM x LSTM      320.0  3.594415e-02  Fail to Reject H0
# 104     KSH   SLSTM x SVR        0.0  9.999991e-01  Fail to Reject H0
# 105     KSH    SVR x KFTS      465.0  8.671988e-07        H0 rejected
# 106     KSH    SVR x PFTS      362.0  3.863854e-03        H0 rejected
# 107     KSH      SVR x RF      465.0  8.666533e-07        H0 rejected
# 108     KSH     SVR x GRU      447.0  5.120404e-06        H0 rejected
# 109     KSH     SVR x RNN      465.0  8.661081e-07        H0 rejected
# 110     KSH    SVR x LSTM      465.0  8.650186e-07        H0 rejected
# 111     KSH   SVR x SLSTM      465.0  8.666533e-07        H0 rejected
# 112    AQB1   KFTS x PFTS        8.5  9.999980e-01  Fail to Reject H0
# 113    AQB1     KFTS x RF       70.0  9.995885e-01  Fail to Reject H0
# 114    AQB1    KFTS x GRU      394.0  4.431454e-04        H0 rejected
# 115    AQB1    KFTS x RNN      354.5  1.519503e-03        H0 rejected
# 116    AQB1   KFTS x LSTM      320.0  1.327523e-02  Fail to Reject H0
# 117    AQB1  KFTS x SLSTM       53.5  9.994354e-01  Fail to Reject H0
# 118    AQB1    KFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 119    AQB1   PFTS x KFTS      456.5  2.033612e-06        H0 rejected
# 120    AQB1     PFTS x RF      299.5  8.407824e-02  Fail to Reject H0
# 121    AQB1    PFTS x GRU      465.0  8.661081e-07        H0 rejected
# 122    AQB1    PFTS x RNN      465.0  8.661081e-07        H0 rejected
# 123    AQB1   PFTS x LSTM      465.0  8.639302e-07        H0 rejected
# 124    AQB1  PFTS x SLSTM      285.5  7.070067e-02  Fail to Reject H0
# 125    AQB1    PFTS x SVR       13.0  9.999968e-01  Fail to Reject H0
# 126    AQB1     RF x KFTS      395.0  4.115301e-04        H0 rejected
# 127    AQB1     RF x PFTS      165.5  9.159218e-01  Fail to Reject H0
# 128    AQB1      RF x GRU      435.0  1.273794e-06        H0 rejected
# 129    AQB1      RF x RNN      461.0  1.292976e-06        H0 rejected
# 130    AQB1     RF x LSTM      401.0  3.238269e-06        H0 rejected
# 131    AQB1    RF x SLSTM      194.0  3.191318e-01  Fail to Reject H0
# 132    AQB1      RF x SVR       83.0  9.989479e-01  Fail to Reject H0
# 133    AQB1    GRU x KFTS       71.0  9.995569e-01  Fail to Reject H0
# 134    AQB1    GRU x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 135    AQB1      GRU x RF        0.0  9.999987e-01  Fail to Reject H0
# 136    AQB1     GRU x RNN        6.0  9.999400e-01  Fail to Reject H0
# 137    AQB1    GRU x LSTM        0.0  9.999993e-01  Fail to Reject H0
# 138    AQB1   GRU x SLSTM       17.5  9.999951e-01  Fail to Reject H0
# 139    AQB1     GRU x SVR        0.0  9.999991e-01  Fail to Reject H0
# 140    AQB1    RNN x KFTS       80.5  9.984805e-01  Fail to Reject H0
# 141    AQB1    RNN x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 142    AQB1      RNN x RF        4.0  9.999987e-01  Fail to Reject H0
# 143    AQB1     RNN x GRU      225.0  5.996948e-05        H0 rejected
# 144    AQB1    RNN x LSTM       67.5  9.990733e-01  Fail to Reject H0
# 145    AQB1   RNN x SLSTM       20.0  9.999938e-01  Fail to Reject H0
# 146    AQB1     RNN x SVR        0.0  9.999991e-01  Fail to Reject H0
# 147    AQB1   LSTM x KFTS      115.0  9.867248e-01  Fail to Reject H0
# 148    AQB1   LSTM x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 149    AQB1     LSTM x RF        5.0  9.999968e-01  Fail to Reject H0
# 150    AQB1    LSTM x GRU      465.0  6.671404e-07        H0 rejected
# 151    AQB1    LSTM x RNN      338.5  9.266574e-04        H0 rejected
# 152    AQB1  LSTM x SLSTM       18.0  9.999802e-01  Fail to Reject H0
# 153    AQB1    LSTM x SVR        0.0  9.999991e-01  Fail to Reject H0
# 154    AQB1  SLSTM x KFTS      324.5  5.645515e-04        H0 rejected
# 155    AQB1  SLSTM x PFTS      149.5  9.292993e-01  Fail to Reject H0
# 156    AQB1    SLSTM x RF      157.0  6.808682e-01  Fail to Reject H0
# 157    AQB1   SLSTM x GRU      447.5  4.858820e-06        H0 rejected
# 158    AQB1   SLSTM x RNN      445.0  6.167495e-06        H0 rejected
# 159    AQB1  SLSTM x LSTM      360.0  1.976558e-05        H0 rejected
# 160    AQB1   SLSTM x SVR       28.0  9.999870e-01  Fail to Reject H0
# 161    AQB1    SVR x KFTS      465.0  8.666533e-07        H0 rejected
# 162    AQB1    SVR x PFTS      452.0  3.167783e-06        H0 rejected
# 163    AQB1      SVR x RF      382.0  1.052056e-03        H0 rejected
# 164    AQB1     SVR x GRU      465.0  8.666533e-07        H0 rejected
# 165    AQB1     SVR x RNN      465.0  8.666533e-07        H0 rejected
# 166    AQB1    SVR x LSTM      465.0  8.666533e-07        H0 rejected
# 167    AQB1   SVR x SLSTM      437.0  1.297080e-05        H0 rejected
# 168    AQB6   KFTS x PFTS       14.0  9.999965e-01  Fail to Reject H0
# 169    AQB6     KFTS x RF        1.5  9.999985e-01  Fail to Reject H0
# 170    AQB6    KFTS x GRU        0.0  9.999991e-01  Fail to Reject H0
# 171    AQB6    KFTS x RNN        0.0  9.999991e-01  Fail to Reject H0
# 172    AQB6   KFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 173    AQB6  KFTS x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 174    AQB6    KFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 175    AQB6   PFTS x KFTS      451.0  3.482154e-06        H0 rejected
# 176    AQB6     PFTS x RF      283.5  7.675300e-02  Fail to Reject H0
# 177    AQB6    PFTS x GRU       29.0  9.999858e-01  Fail to Reject H0
# 178    AQB6    PFTS x RNN       29.0  9.999858e-01  Fail to Reject H0
# 179    AQB6   PFTS x LSTM        2.0  9.999989e-01  Fail to Reject H0
# 180    AQB6  PFTS x SLSTM      138.0  9.572197e-01  Fail to Reject H0
# 181    AQB6    PFTS x SVR        1.0  9.999990e-01  Fail to Reject H0
# 182    AQB6     RF x KFTS      433.5  1.485629e-06        H0 rejected
# 183    AQB6     RF x PFTS      151.5  9.232470e-01  Fail to Reject H0
# 184    AQB6      RF x GRU       95.0  9.959634e-01  Fail to Reject H0
# 185    AQB6      RF x RNN      105.0  9.956369e-01  Fail to Reject H0
# 186    AQB6     RF x LSTM       92.0  9.980748e-01  Fail to Reject H0
# 187    AQB6    RF x SLSTM      112.0  9.934078e-01  Fail to Reject H0
# 188    AQB6      RF x SVR       72.0  9.995190e-01  Fail to Reject H0
# 189    AQB6    GRU x KFTS      465.0  8.666533e-07        H0 rejected
# 190    AQB6    GRU x PFTS      436.0  1.416869e-05        H0 rejected
# 191    AQB6      GRU x RF      340.0  4.036553e-03        H0 rejected
# 192    AQB6     GRU x RNN      230.5  1.590585e-01  Fail to Reject H0
# 193    AQB6    GRU x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 194    AQB6   GRU x SLSTM      257.0  1.965064e-01  Fail to Reject H0
# 195    AQB6     GRU x SVR       21.5  9.999929e-01  Fail to Reject H0
# 196    AQB6    RNN x KFTS      465.0  8.655632e-07        H0 rejected
# 197    AQB6    RNN x PFTS      436.0  1.416869e-05        H0 rejected
# 198    AQB6      RNN x RF      360.0  4.363058e-03        H0 rejected
# 199    AQB6     RNN x GRU      147.5  8.409415e-01  Fail to Reject H0
# 200    AQB6    RNN x LSTM        0.0  9.999987e-01  Fail to Reject H0
# 201    AQB6   RNN x SLSTM      261.5  1.706672e-01  Fail to Reject H0
# 202    AQB6     RNN x SVR       14.5  9.999963e-01  Fail to Reject H0
# 203    AQB6   LSTM x KFTS      465.0  8.655632e-07        H0 rejected
# 204    AQB6   LSTM x PFTS      463.0  1.060689e-06        H0 rejected
# 205    AQB6     LSTM x RF      373.0  1.925245e-03        H0 rejected
# 206    AQB6    LSTM x GRU      465.0  8.531088e-07        H0 rejected
# 207    AQB6    LSTM x RNN      435.0  1.255868e-06        H0 rejected
# 208    AQB6  LSTM x SLSTM      306.0  6.528564e-02  Fail to Reject H0
# 209    AQB6    LSTM x SVR       49.0  9.998656e-01  Fail to Reject H0
# 210    AQB6  SLSTM x KFTS      465.0  8.661081e-07        H0 rejected
# 211    AQB6  SLSTM x PFTS      297.0  4.278027e-02  Fail to Reject H0
# 212    AQB6    SLSTM x RF      353.0  6.592238e-03        H0 rejected
# 213    AQB6   SLSTM x GRU      178.0  8.034936e-01  Fail to Reject H0
# 214    AQB6   SLSTM x RNN      173.5  8.293328e-01  Fail to Reject H0
# 215    AQB6  SLSTM x LSTM      159.0  9.347144e-01  Fail to Reject H0
# 216    AQB6   SLSTM x SVR        1.0  9.999986e-01  Fail to Reject H0
# 217    AQB6    SVR x KFTS      465.0  8.671988e-07        H0 rejected
# 218    AQB6    SVR x PFTS      464.0  9.604606e-07        H0 rejected
# 219    AQB6      SVR x RF      393.0  4.810300e-04        H0 rejected
# 220    AQB6     SVR x GRU      443.5  7.115585e-06        H0 rejected
# 221    AQB6     SVR x RNN      450.5  3.660513e-06        H0 rejected
# 222    AQB6    SVR x LSTM      386.0  1.343616e-04        H0 rejected
# 223    AQB6   SVR x SLSTM      434.0  1.424452e-06        H0 rejected
# 224   AQB12   KFTS x PFTS        0.0  9.999991e-01  Fail to Reject H0
# 225   AQB12     KFTS x RF       65.5  9.997051e-01  Fail to Reject H0
# 226   AQB12    KFTS x GRU        0.0  9.999991e-01  Fail to Reject H0
# 227   AQB12    KFTS x RNN        0.0  9.999991e-01  Fail to Reject H0
# 228   AQB12   KFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 229   AQB12  KFTS x SLSTM        0.0  9.999991e-01  Fail to Reject H0
# 230   AQB12    KFTS x SVR        0.0  9.999991e-01  Fail to Reject H0
# 231   AQB12   PFTS x KFTS      465.0  8.585053e-07        H0 rejected
# 232   AQB12     PFTS x RF      262.0  2.718752e-01  Fail to Reject H0
# 233   AQB12    PFTS x GRU        0.0  9.999991e-01  Fail to Reject H0
# 234   AQB12    PFTS x RNN        0.0  9.999991e-01  Fail to Reject H0
# 235   AQB12   PFTS x LSTM        0.0  9.999991e-01  Fail to Reject H0
# 236   AQB12  PFTS x SLSTM       34.5  9.999768e-01  Fail to Reject H0
# 237   AQB12    PFTS x SVR        3.0  9.999988e-01  Fail to Reject H0
# 238   AQB12     RF x KFTS      399.5  2.948851e-04        H0 rejected
# 239   AQB12     RF x PFTS      203.0  7.281248e-01  Fail to Reject H0
# 240   AQB12      RF x GRU       88.0  9.985220e-01  Fail to Reject H0
# 241   AQB12      RF x RNN       75.0  9.994013e-01  Fail to Reject H0
# 242   AQB12     RF x LSTM       87.0  9.986181e-01  Fail to Reject H0
# 243   AQB12    RF x SLSTM       87.0  9.986188e-01  Fail to Reject H0
# 244   AQB12      RF x SVR       25.0  9.999901e-01  Fail to Reject H0
# 245   AQB12    GRU x KFTS      465.0  8.661081e-07        H0 rejected
# 246   AQB12    GRU x PFTS      465.0  8.655632e-07        H0 rejected
# 247   AQB12      GRU x RF      377.0  1.477974e-03        H0 rejected
# 248   AQB12     GRU x RNN        0.0  9.999991e-01  Fail to Reject H0
# 249   AQB12    GRU x LSTM       73.5  9.990911e-01  Fail to Reject H0
# 250   AQB12   GRU x SLSTM      367.0  2.830409e-03        H0 rejected
# 251   AQB12     GRU x SVR      229.5  5.246050e-01  Fail to Reject H0
# 252   AQB12    RNN x KFTS      465.0  8.661081e-07        H0 rejected
# 253   AQB12    RNN x PFTS      465.0  8.661081e-07        H0 rejected
# 254   AQB12      RNN x RF      390.0  5.986691e-04        H0 rejected
# 255   AQB12     RNN x GRU      465.0  8.585053e-07        H0 rejected
# 256   AQB12    RNN x LSTM      465.0  8.612141e-07        H0 rejected
# 257   AQB12   RNN x SLSTM      401.0  2.641823e-04        H0 rejected
# 258   AQB12     RNN x SVR      330.0  2.245096e-02  Fail to Reject H0
# 259   AQB12   LSTM x KFTS      465.0  8.666533e-07        H0 rejected
# 260   AQB12   LSTM x PFTS      465.0  8.639302e-07        H0 rejected
# 261   AQB12     LSTM x RF      378.0  1.381920e-03        H0 rejected
# 262   AQB12    LSTM x GRU      361.5  9.089220e-04        H0 rejected
# 263   AQB12    LSTM x RNN        0.0  9.999991e-01  Fail to Reject H0
# 264   AQB12  LSTM x SLSTM      373.0  1.922437e-03        H0 rejected
# 265   AQB12    LSTM x SVR      246.5  3.866812e-01  Fail to Reject H0
# 266   AQB12  SLSTM x KFTS      465.0  8.639302e-07        H0 rejected
# 267   AQB12  SLSTM x PFTS      430.5  2.320950e-05        H0 rejected
# 268   AQB12    SLSTM x RF      378.0  1.381204e-03        H0 rejected
# 269   AQB12   SLSTM x GRU       98.0  9.971696e-01  Fail to Reject H0
# 270   AQB12   SLSTM x RNN       64.0  9.997358e-01  Fail to Reject H0
# 271   AQB12  SLSTM x LSTM       92.0  9.980776e-01  Fail to Reject H0
# 272   AQB12   SLSTM x SVR        0.0  9.999991e-01  Fail to Reject H0
# 273   AQB12    SVR x KFTS      465.0  8.666533e-07        H0 rejected
# 274   AQB12    SVR x PFTS      462.0  1.176710e-06        H0 rejected
# 275   AQB12      SVR x RF      440.0  9.864742e-06        H0 rejected
# 276   AQB12     SVR x GRU      235.5  4.753950e-01  Fail to Reject H0
# 277   AQB12     SVR x RNN      135.0  9.775490e-01  Fail to Reject H0
# 278   AQB12    SVR x LSTM      218.5  6.133188e-01  Fail to Reject H0
# 279   AQB12   SVR x SLSTM      465.0  8.655632e-07        H0 rejected

# %% [markdown]
# ### Rankings

# %%
from scipy import stats
import itertools

competing_methods = list(methods)#['KFTS', 'PFTS', 'VAR', 'SLSTM', 'LSTM', 'GRU', 'RNN', 'RF', 'SVR']

anova_test = stats.kruskal #stats.friedmanchisquare #stats.kruskal #stats.friedmanchisquare
post_hoc_test = stats.wilcoxon

final_ranking = []

for dataset in datasets:
  #if dataset != 'SONDA':
    samples = []
    for method in competing_methods:
      sample = df[(df['ds'] == dataset) & (df['model'] == method)]['avg_nrmse']
      samples.append(sample)

    result = anova_test(*samples)

    if result.pvalue < alpha:
      
      post_hoc = {k: 0 for k in competing_methods}
      
      for a,b in itertools.product(competing_methods , competing_methods):
        if a != b:
          i = competing_methods.index(a)
          j = competing_methods.index(b)
          result2 = post_hoc_test(samples[i],samples[j],alternative='greater') 

          if result2.pvalue > alpha:
            post_hoc[a] += 1
      
      print(post_hoc)
      ranking = [len(methods) - v for v in post_hoc.values()]

      ranking.insert(0, dataset)

      final_ranking.append(ranking)


columns = competing_methods.copy()

columns.insert(0,'Dataset')

df_final_ranking = pd.DataFrame(final_ranking, columns=columns) 

#print("")
df_final_ranking
# Out:
# {'KFTS': 7, 'PFTS': 6, 'RF': 5, 'GRU': 4, 'RNN': 4, 'LSTM': 2, 'SLSTM': 1, 'SVR': 0}
# {'KFTS': 6, 'PFTS': 1, 'RF': 6, 'GRU': 5, 'RNN': 7, 'LSTM': 3, 'SLSTM': 3, 'SVR': 0}
# {'KFTS': 5, 'PFTS': 3, 'RF': 3, 'GRU': 7, 'RNN': 6, 'LSTM': 5, 'SLSTM': 3, 'SVR': 0}
# {'KFTS': 7, 'PFTS': 6, 'RF': 6, 'GRU': 4, 'RNN': 4, 'LSTM': 2, 'SLSTM': 5, 'SVR': 0}
# {'KFTS': 7, 'PFTS': 6, 'RF': 6, 'GRU': 3, 'RNN': 1, 'LSTM': 2, 'SLSTM': 4, 'SVR': 3}
#   Dataset  KFTS  PFTS  RF  GRU  RNN  LSTM  SLSTM  SVR
# 0     AEC     1     2   3    4    4     6      7    8
# 1     KSH     2     7   2    3    1     5      5    8
# 2    AQB1     3     5   5    1    2     3      5    8
# 3    AQB6     1     2   2    4    4     6      3    8
# 4   AQB12     1     2   2    5    7     6      4    5

# %%
df_final_ranking.to_csv(r'final_ranking.csv', index = False, header=True)

# %%
#post_hoc.values()
